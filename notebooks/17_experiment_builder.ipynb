# %% [markdown]
# # Football experiment builder
#
# Run the next cell to open the local UI. Keep this kernel running while using it. Choose data, features, folds, models, and reports in the browser. [UI guide](../docs/analytics/ui.md).
#
# This launcher is intentionally saved unexecuted; running the cell starts a local server.

# %%
from xdiyo_analytics.ui import launch_ui

builder = launch_ui(workspace=r"C:\Users\luisi\Documents\Programming\Python\xDiyo")

# %%
# Optional: display the same UI inside this notebook.
# builder.show()

# When finished, stop the local server.
# builder.close()
