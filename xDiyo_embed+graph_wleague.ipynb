# %%
from football_dataset_xDiyoFire import *
from utils_xDiyo_wleague import *
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.nn import GCNConv, GATConv
from sklearn.metrics import precision_score, recall_score, mean_squared_error, mean_absolute_error,accuracy_score, f1_score
import matplotlib.pyplot as plt
import random
from torch.profiler import profile, ProfilerActivity
import math
from sklearn.manifold import TSNE

# %%
random.seed(69)
np.random.seed(69)
torch.manual_seed(69)
if torch.cuda.is_available():
    torch.cuda.manual_seed(69)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
test_names = ['Premier_League_20_21','Premier_League_21_22','Premier_League_22_23','Premier_League_23_24',
            'La_Liga_20_21','La_Liga_21_22','La_Liga_22_23','La_Liga_23_24',
            'Serie_A_20_21','Serie_A_21_22','Serie_A_22_23', 'Serie_A_23_24', 
            'Bundesliga_20_21','Bundesliga_21_22','Bundesliga_22_23', 'Bundesliga_23_24']
train_df,val_df,test_df,league_dict = split_and_merge_leagues(test_names, 0.8, 0.1, 0.1)
atk_headers,def_headers = divide_stats(stat_type='older_stats')
atk_avgs = calculate_mean_std(train_df, atk_headers)
def_avgs = calculate_mean_std(train_df, def_headers)
mu_atk,sigma_atk = extract_averages(atk_avgs, atk_headers)
mu_def,sigma_def = extract_averages(def_avgs, def_headers)
team_names = ['<PAD>']+sorted(train_df['home_team'].unique())
team2id = {name: idx for idx, name in enumerate(team_names)}

# %%
# Bundle everything you want to save into a dictionary
save_cache(
    'cached_preprocessing_waverage_heatmap.pkl',
    atk_headers=atk_headers,
    def_headers=def_headers,
    atk_avgs=atk_avgs,
    def_avgs=def_avgs,
    mu_atk=mu_atk,
    sigma_atk=sigma_atk,
    mu_def=mu_def,
    sigma_def=sigma_def,
    team_names=team_names,
    team2id=team2id
)

# %%
cached_data = load_cache('cached_preprocessing_waverage_heatmap.pkl')

atk_headers, def_headers, atk_avgs, def_avgs, mu_atk, sigma_atk, mu_def, sigma_def, team_names, team2id = cached_data['atk_headers'], cached_data['def_headers'], cached_data['atk_avgs'], cached_data['def_avgs'], cached_data['mu_atk'], cached_data['sigma_atk'], cached_data['mu_def'], cached_data['sigma_def'], cached_data['team_names'], cached_data['team2id']
# Out:
# c:\Users\luisi\Documents\Programming\Projects\Transformers\transformers\Lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
history_len = 8
n_x,n_y = 15,10
flatten_h, reverse_h = False, False
raw_train = FootballDataset(train_df, history_len, team2id, n_x, n_y, flatten_h, reverse_h, stat_type='older_stats')
raw_val = FootballDataset(val_df, history_len, team2id, n_x, n_y, flatten_h, reverse_h, stat_type='older_stats')
raw_test = FootballDataset(test_df, history_len, team2id, n_x, n_y, flatten_h, reverse_h, stat_type='older_stats')

# %%
history_len = 8
n_x,n_y = 15,10
precompute_data(raw_train, f'data/{history_len}_{n_x}_{n_y}/train', start_idx=0)
precompute_data(raw_val, f'data/{history_len}_{n_x}_{n_y}/val', start_idx=0)
precompute_data(raw_test, f'data/{history_len}_{n_x}_{n_y}/test', start_idx=0)
# Out:
# Preprocessed and saved sample 1/4624
# Preprocessed and saved sample 2/4624
# Preprocessed and saved sample 3/4624
# Preprocessed and saved sample 4/4624
# Preprocessed and saved sample 5/4624
# Preprocessed and saved sample 6/4624
# Preprocessed and saved sample 7/4624
# Preprocessed and saved sample 8/4624
# Preprocessed and saved sample 9/4624
# Preprocessed and saved sample 10/4624
# Preprocessed and saved sample 11/4624
# Preprocessed and saved sample 12/4624
# Preprocessed and saved sample 13/4624
# Preprocessed and saved sample 14/4624
# Preprocessed and saved sample 15/4624
# Preprocessed and saved sample 16/4624
# Preprocessed and saved sample 17/4624
# Preprocessed and saved sample 18/4624
# Preprocessed and saved sample 19/4624
# Preprocessed and saved sample 20/4624
# Preprocessed and saved sample 21/4624
# Preprocessed and saved sample 22/4624
# Preprocessed and saved sample 23/4624
# Preprocessed and saved sample 24/4624
# Preprocessed and saved sample 25/4624
# Preprocessed and saved sample 26/4624
# Preprocessed and saved sample 27/4624
# Preprocessed and saved sample 28/4624
# Preprocessed and saved sample 29/4624
# Preprocessed and saved sample 30/4624
# Preprocessed and saved sample 31/4624
# Preprocessed and saved sample 32/4624
# Preprocessed and saved sample 33/4624
# Preprocessed and saved sample 34/4624
# Preprocessed and saved sample 35/4624
# Preprocessed and saved sample 36/4624
# Preprocessed and saved sample 37/4624
# Preprocessed and saved sample 38/4624
# Preprocessed and saved sample 39/4624
# Preprocessed and saved sample 40/4624
# Preprocessed and saved sample 41/4624
# Preprocessed and saved sample 42/4624
# Preprocessed and saved sample 43/4624
# Preprocessed and saved sample 44/4624
# Preprocessed and saved sample 45/4624
# Preprocessed and saved sample 46/4624
# Preprocessed and saved sample 47/4624
# Preprocessed and saved sample 48/4624
# Preprocessed and saved sample 49/4624
# Preprocessed and saved sample 50/4624
# Preprocessed and saved sample 51/4624
# Preprocessed and saved sample 52/4624
# Preprocessed and saved sample 53/4624
# Preprocessed and saved sample 54/4624
# Preprocessed and saved sample 55/4624
# Preprocessed and saved sample 56/4624
# Preprocessed and saved sample 57/4624
# Preprocessed and saved sample 58/4624
# Preprocessed and saved sample 59/4624
# Preprocessed and saved sample 60/4624
# Preprocessed and saved sample 61/4624
# Preprocessed and saved sample 62/4624
# Preprocessed and saved sample 63/4624
# Preprocessed and saved sample 64/4624
# Preprocessed and saved sample 65/4624
# Preprocessed and saved sample 66/4624
# Preprocessed and saved sample 67/4624
# Preprocessed and saved sample 68/4624
# Preprocessed and saved sample 69/4624
# Preprocessed and saved sample 70/4624
# Preprocessed and saved sample 71/4624
# Preprocessed and saved sample 72/4624
# Preprocessed and saved sample 73/4624
# Preprocessed and saved sample 74/4624
# Preprocessed and saved sample 75/4624
# Preprocessed and saved sample 76/4624
# Preprocessed and saved sample 77/4624
# Preprocessed and saved sample 78/4624
# Preprocessed and saved sample 79/4624
# Preprocessed and saved sample 80/4624
# Preprocessed and saved sample 81/4624
# Preprocessed and saved sample 82/4624
# Preprocessed and saved sample 83/4624
# Preprocessed and saved sample 84/4624
# Preprocessed and saved sample 85/4624
# Preprocessed and saved sample 86/4624
# Preprocessed and saved sample 87/4624
# Preprocessed and saved sample 88/4624
# Preprocessed and saved sample 89/4624
# Preprocessed and saved sample 90/4624
# Preprocessed and saved sample 91/4624
# Preprocessed and saved sample 92/4624
# Preprocessed and saved sample 93/4624
# Preprocessed and saved sample 94/4624
# Preprocessed and saved sample 95/4624
# Preprocessed and saved sample 96/4624
# Preprocessed and saved sample 97/4624
# Preprocessed and saved sample 98/4624
# Preprocessed and saved sample 99/4624
# Preprocessed and saved sample 100/4624
# Preprocessed and saved sample 101/4624
# Preprocessed and saved sample 102/4624
# Preprocessed and saved sample 103/4624
# Preprocessed and saved sample 104/4624
# Preprocessed and saved sample 105/4624
# Preprocessed and saved sample 106/4624
# Preprocessed and saved sample 107/4624
# Preprocessed and saved sample 108/4624
# Preprocessed and saved sample 109/4624
# Preprocessed and saved sample 110/4624
# Preprocessed and saved sample 111/4624
# Preprocessed and saved sample 112/4624
# Preprocessed and saved sample 113/4624
# Preprocessed and saved sample 114/4624
# Preprocessed and saved sample 115/4624
# Preprocessed and saved sample 116/4624
# Preprocessed and saved sample 117/4624
# Preprocessed and saved sample 118/4624
# Preprocessed and saved sample 119/4624
# Preprocessed and saved sample 120/4624
# Preprocessed and saved sample 121/4624
# Preprocessed and saved sample 122/4624
# Preprocessed and saved sample 123/4624
# Preprocessed and saved sample 124/4624
# Preprocessed and saved sample 125/4624
# Preprocessed and saved sample 126/4624
# Preprocessed and saved sample 127/4624
# Preprocessed and saved sample 128/4624
# Preprocessed and saved sample 129/4624
# Preprocessed and saved sample 130/4624
# Preprocessed and saved sample 131/4624
# Preprocessed and saved sample 132/4624
# Preprocessed and saved sample 133/4624
# Preprocessed and saved sample 134/4624
# Preprocessed and saved sample 135/4624
# Preprocessed and saved sample 136/4624
# Preprocessed and saved sample 137/4624
# Preprocessed and saved sample 138/4624
# Preprocessed and saved sample 139/4624
# Preprocessed and saved sample 140/4624
# Preprocessed and saved sample 141/4624
# Preprocessed and saved sample 142/4624
# Preprocessed and saved sample 143/4624
# Preprocessed and saved sample 144/4624
# Preprocessed and saved sample 145/4624
# Preprocessed and saved sample 146/4624
# Preprocessed and saved sample 147/4624
# Preprocessed and saved sample 148/4624
# Preprocessed and saved sample 149/4624
# Preprocessed and saved sample 150/4624
# Preprocessed and saved sample 151/4624
# Preprocessed and saved sample 152/4624
# Preprocessed and saved sample 153/4624
# Preprocessed and saved sample 154/4624
# Preprocessed and saved sample 155/4624
# Preprocessed and saved sample 156/4624
# Preprocessed and saved sample 157/4624
# Preprocessed and saved sample 158/4624
# Preprocessed and saved sample 159/4624
# Preprocessed and saved sample 160/4624
# Preprocessed and saved sample 161/4624
# Preprocessed and saved sample 162/4624
# Preprocessed and saved sample 163/4624
# Preprocessed and saved sample 164/4624
# Preprocessed and saved sample 165/4624
# Preprocessed and saved sample 166/4624
# Preprocessed and saved sample 167/4624
# Preprocessed and saved sample 168/4624
# Preprocessed and saved sample 169/4624
# Preprocessed and saved sample 170/4624
# Preprocessed and saved sample 171/4624
# Preprocessed and saved sample 172/4624
# Preprocessed and saved sample 173/4624
# Preprocessed and saved sample 174/4624
# Preprocessed and saved sample 175/4624
# Preprocessed and saved sample 176/4624
# Preprocessed and saved sample 177/4624
# Preprocessed and saved sample 178/4624
# Preprocessed and saved sample 179/4624
# Preprocessed and saved sample 180/4624
# Preprocessed and saved sample 181/4624
# Preprocessed and saved sample 182/4624
# Preprocessed and saved sample 183/4624
# Preprocessed and saved sample 184/4624
# Preprocessed and saved sample 185/4624
# Preprocessed and saved sample 186/4624
# Preprocessed and saved sample 187/4624
# Preprocessed and saved sample 188/4624
# Preprocessed and saved sample 189/4624
# Preprocessed and saved sample 190/4624
# Preprocessed and saved sample 191/4624
# Preprocessed and saved sample 192/4624
# Preprocessed and saved sample 193/4624
# Preprocessed and saved sample 194/4624
# Preprocessed and saved sample 195/4624
# Preprocessed and saved sample 196/4624
# Preprocessed and saved sample 197/4624
# Preprocessed and saved sample 198/4624
# Preprocessed and saved sample 199/4624
# Preprocessed and saved sample 200/4624
# Preprocessed and saved sample 201/4624
# Preprocessed and saved sample 202/4624
# Preprocessed and saved sample 203/4624
# Preprocessed and saved sample 204/4624
# Preprocessed and saved sample 205/4624
# Preprocessed and saved sample 206/4624
# Preprocessed and saved sample 207/4624
# Preprocessed and saved sample 208/4624
# Preprocessed and saved sample 209/4624
# Preprocessed and saved sample 210/4624
# Preprocessed and saved sample 211/4624
# Preprocessed and saved sample 212/4624
# Preprocessed and saved sample 213/4624
# Preprocessed and saved sample 214/4624
# Preprocessed and saved sample 215/4624
# Preprocessed and saved sample 216/4624
# Preprocessed and saved sample 217/4624
# Preprocessed and saved sample 218/4624
# Preprocessed and saved sample 219/4624
# Preprocessed and saved sample 220/4624
# Preprocessed and saved sample 221/4624
# Preprocessed and saved sample 222/4624
# Preprocessed and saved sample 223/4624
# Preprocessed and saved sample 224/4624
# Preprocessed and saved sample 225/4624
# Preprocessed and saved sample 226/4624
# Preprocessed and saved sample 227/4624
# Preprocessed and saved sample 228/4624
# Preprocessed and saved sample 229/4624
# Preprocessed and saved sample 230/4624
# Preprocessed and saved sample 231/4624
# Preprocessed and saved sample 232/4624
# Preprocessed and saved sample 233/4624
# Preprocessed and saved sample 234/4624
# Preprocessed and saved sample 235/4624
# Preprocessed and saved sample 236/4624
# Preprocessed and saved sample 237/4624
# Preprocessed and saved sample 238/4624
# Preprocessed and saved sample 239/4624
# Preprocessed and saved sample 240/4624
# Preprocessed and saved sample 241/4624
# Preprocessed and saved sample 242/4624
# Preprocessed and saved sample 243/4624
# Preprocessed and saved sample 244/4624
# Preprocessed and saved sample 245/4624
# Preprocessed and saved sample 246/4624
# Preprocessed and saved sample 247/4624
# Preprocessed and saved sample 248/4624
# Preprocessed and saved sample 249/4624
# Preprocessed and saved sample 250/4624
# Preprocessed and saved sample 251/4624
# Preprocessed and saved sample 252/4624
# Preprocessed and saved sample 253/4624
# Preprocessed and saved sample 254/4624
# Preprocessed and saved sample 255/4624
# Preprocessed and saved sample 256/4624
# Preprocessed and saved sample 257/4624
# Preprocessed and saved sample 258/4624
# Preprocessed and saved sample 259/4624
# Preprocessed and saved sample 260/4624
# Preprocessed and saved sample 261/4624
# Preprocessed and saved sample 262/4624
# Preprocessed and saved sample 263/4624
# Preprocessed and saved sample 264/4624
# Preprocessed and saved sample 265/4624
# Preprocessed and saved sample 266/4624
# Preprocessed and saved sample 267/4624
# Preprocessed and saved sample 268/4624
# Preprocessed and saved sample 269/4624
# Preprocessed and saved sample 270/4624
# Preprocessed and saved sample 271/4624
# Preprocessed and saved sample 272/4624
# Preprocessed and saved sample 273/4624
# Preprocessed and saved sample 274/4624
# Preprocessed and saved sample 275/4624
# Preprocessed and saved sample 276/4624
# Preprocessed and saved sample 277/4624
# Preprocessed and saved sample 278/4624
# Preprocessed and saved sample 279/4624
# Preprocessed and saved sample 280/4624
# Preprocessed and saved sample 281/4624
# Preprocessed and saved sample 282/4624
# Preprocessed and saved sample 283/4624
# Preprocessed and saved sample 284/4624
# Preprocessed and saved sample 285/4624
# Preprocessed and saved sample 286/4624
# Preprocessed and saved sample 287/4624
# Preprocessed and saved sample 288/4624
# Preprocessed and saved sample 289/4624
# Preprocessed and saved sample 290/4624
# Preprocessed and saved sample 291/4624
# Preprocessed and saved sample 292/4624
# Preprocessed and saved sample 293/4624
# Preprocessed and saved sample 294/4624
# Preprocessed and saved sample 295/4624
# Preprocessed and saved sample 296/4624
# Preprocessed and saved sample 297/4624
# Preprocessed and saved sample 298/4624
# Preprocessed and saved sample 299/4624
# Preprocessed and saved sample 300/4624
# Preprocessed and saved sample 301/4624
# Preprocessed and saved sample 302/4624
# Preprocessed and saved sample 303/4624
# Preprocessed and saved sample 304/4624
# Preprocessed and saved sample 305/4624
# Preprocessed and saved sample 306/4624
# Preprocessed and saved sample 307/4624
# Preprocessed and saved sample 308/4624
# Preprocessed and saved sample 309/4624
# Preprocessed and saved sample 310/4624
# Preprocessed and saved sample 311/4624
# Preprocessed and saved sample 312/4624
# Preprocessed and saved sample 313/4624
# Preprocessed and saved sample 314/4624
# Preprocessed and saved sample 315/4624
# Preprocessed and saved sample 316/4624
# Preprocessed and saved sample 317/4624
# Preprocessed and saved sample 318/4624
# Preprocessed and saved sample 319/4624
# Preprocessed and saved sample 320/4624
# Preprocessed and saved sample 321/4624
# Preprocessed and saved sample 322/4624
# Preprocessed and saved sample 323/4624
# Preprocessed and saved sample 324/4624
# Preprocessed and saved sample 325/4624
# Preprocessed and saved sample 326/4624
# Preprocessed and saved sample 327/4624
# Preprocessed and saved sample 328/4624
# Preprocessed and saved sample 329/4624
# Preprocessed and saved sample 330/4624
# Preprocessed and saved sample 331/4624
# Preprocessed and saved sample 332/4624
# Preprocessed and saved sample 333/4624
# Preprocessed and saved sample 334/4624
# Preprocessed and saved sample 335/4624
# Preprocessed and saved sample 336/4624
# Preprocessed and saved sample 337/4624
# Preprocessed and saved sample 338/4624
# Preprocessed and saved sample 339/4624
# Preprocessed and saved sample 340/4624
# Preprocessed and saved sample 341/4624
# Preprocessed and saved sample 342/4624
# Preprocessed and saved sample 343/4624
# Preprocessed and saved sample 344/4624
# Preprocessed and saved sample 345/4624
# Preprocessed and saved sample 346/4624
# Preprocessed and saved sample 347/4624
# Preprocessed and saved sample 348/4624
# Preprocessed and saved sample 349/4624
# Preprocessed and saved sample 350/4624
# Preprocessed and saved sample 351/4624
# Preprocessed and saved sample 352/4624
# Preprocessed and saved sample 353/4624
# Preprocessed and saved sample 354/4624
# Preprocessed and saved sample 355/4624
# Preprocessed and saved sample 356/4624
# Preprocessed and saved sample 357/4624
# Preprocessed and saved sample 358/4624
# Preprocessed and saved sample 359/4624
# Preprocessed and saved sample 360/4624
# Preprocessed and saved sample 361/4624
# Preprocessed and saved sample 362/4624
# Preprocessed and saved sample 363/4624
# Preprocessed and saved sample 364/4624
# Preprocessed and saved sample 365/4624
# Preprocessed and saved sample 366/4624
# Preprocessed and saved sample 367/4624
# Preprocessed and saved sample 368/4624
# Preprocessed and saved sample 369/4624
# Preprocessed and saved sample 370/4624
# Preprocessed and saved sample 371/4624
# Preprocessed and saved sample 372/4624
# Preprocessed and saved sample 373/4624
# Preprocessed and saved sample 374/4624
# Preprocessed and saved sample 375/4624
# Preprocessed and saved sample 376/4624
# Preprocessed and saved sample 377/4624
# Preprocessed and saved sample 378/4624
# Preprocessed and saved sample 379/4624
# Preprocessed and saved sample 380/4624
# Preprocessed and saved sample 381/4624
# Preprocessed and saved sample 382/4624
# Preprocessed and saved sample 383/4624
# Preprocessed and saved sample 384/4624
# Preprocessed and saved sample 385/4624
# Preprocessed and saved sample 386/4624
# Preprocessed and saved sample 387/4624
# Preprocessed and saved sample 388/4624
# Preprocessed and saved sample 389/4624
# Preprocessed and saved sample 390/4624
# Preprocessed and saved sample 391/4624
# Preprocessed and saved sample 392/4624
# Preprocessed and saved sample 393/4624
# Preprocessed and saved sample 394/4624
# Preprocessed and saved sample 395/4624
# Preprocessed and saved sample 396/4624
# Preprocessed and saved sample 397/4624
# Preprocessed and saved sample 398/4624
# Preprocessed and saved sample 399/4624
# Preprocessed and saved sample 400/4624
# Preprocessed and saved sample 401/4624
# Preprocessed and saved sample 402/4624
# Preprocessed and saved sample 403/4624
# Preprocessed and saved sample 404/4624
# Preprocessed and saved sample 405/4624
# Preprocessed and saved sample 406/4624
# Preprocessed and saved sample 407/4624
# Preprocessed and saved sample 408/4624
# Preprocessed and saved sample 409/4624
# Preprocessed and saved sample 410/4624
# Preprocessed and saved sample 411/4624
# Preprocessed and saved sample 412/4624
# Preprocessed and saved sample 413/4624
# Preprocessed and saved sample 414/4624
# Preprocessed and saved sample 415/4624
# Preprocessed and saved sample 416/4624
# Preprocessed and saved sample 417/4624
# Preprocessed and saved sample 418/4624
# Preprocessed and saved sample 419/4624
# Preprocessed and saved sample 420/4624
# Preprocessed and saved sample 421/4624
# Preprocessed and saved sample 422/4624
# Preprocessed and saved sample 423/4624
# Preprocessed and saved sample 424/4624
# Preprocessed and saved sample 425/4624
# Preprocessed and saved sample 426/4624
# Preprocessed and saved sample 427/4624
# Preprocessed and saved sample 428/4624
# Preprocessed and saved sample 429/4624
# Preprocessed and saved sample 430/4624
# Preprocessed and saved sample 431/4624
# Preprocessed and saved sample 432/4624
# Preprocessed and saved sample 433/4624
# Preprocessed and saved sample 434/4624
# Preprocessed and saved sample 435/4624
# Preprocessed and saved sample 436/4624
# Preprocessed and saved sample 437/4624
# Preprocessed and saved sample 438/4624
# Preprocessed and saved sample 439/4624
# Preprocessed and saved sample 440/4624
# Preprocessed and saved sample 441/4624
# Preprocessed and saved sample 442/4624
# Preprocessed and saved sample 443/4624
# Preprocessed and saved sample 444/4624
# Preprocessed and saved sample 445/4624
# Preprocessed and saved sample 446/4624
# Preprocessed and saved sample 447/4624
# Preprocessed and saved sample 448/4624
# Preprocessed and saved sample 449/4624
# Preprocessed and saved sample 450/4624
# Preprocessed and saved sample 451/4624
# Preprocessed and saved sample 452/4624
# Preprocessed and saved sample 453/4624
# Preprocessed and saved sample 454/4624
# Preprocessed and saved sample 455/4624
# Preprocessed and saved sample 456/4624
# Preprocessed and saved sample 457/4624
# Preprocessed and saved sample 458/4624
# Preprocessed and saved sample 459/4624
# Preprocessed and saved sample 460/4624
# Preprocessed and saved sample 461/4624
# Preprocessed and saved sample 462/4624
# Preprocessed and saved sample 463/4624
# Preprocessed and saved sample 464/4624
# Preprocessed and saved sample 465/4624
# Preprocessed and saved sample 466/4624
# Preprocessed and saved sample 467/4624
# Preprocessed and saved sample 468/4624
# Preprocessed and saved sample 469/4624
# Preprocessed and saved sample 470/4624
# Preprocessed and saved sample 471/4624
# Preprocessed and saved sample 472/4624
# Preprocessed and saved sample 473/4624
# Preprocessed and saved sample 474/4624
# Preprocessed and saved sample 475/4624
# Preprocessed and saved sample 476/4624
# Preprocessed and saved sample 477/4624
# Preprocessed and saved sample 478/4624
# Preprocessed and saved sample 479/4624
# Preprocessed and saved sample 480/4624
# Preprocessed and saved sample 481/4624
# Preprocessed and saved sample 482/4624
# Preprocessed and saved sample 483/4624
# Preprocessed and saved sample 484/4624
# Preprocessed and saved sample 485/4624
# Preprocessed and saved sample 486/4624
# Preprocessed and saved sample 487/4624
# Preprocessed and saved sample 488/4624
# Preprocessed and saved sample 489/4624
# Preprocessed and saved sample 490/4624
# Preprocessed and saved sample 491/4624
# Preprocessed and saved sample 492/4624
# Preprocessed and saved sample 493/4624
# Preprocessed and saved sample 494/4624
# Preprocessed and saved sample 495/4624
# Preprocessed and saved sample 496/4624
# Preprocessed and saved sample 497/4624
# Preprocessed and saved sample 498/4624
# Preprocessed and saved sample 499/4624
# Preprocessed and saved sample 500/4624
# Preprocessed and saved sample 501/4624
# Preprocessed and saved sample 502/4624
# Preprocessed and saved sample 503/4624
# Preprocessed and saved sample 504/4624
# Preprocessed and saved sample 505/4624
# Preprocessed and saved sample 506/4624
# Preprocessed and saved sample 507/4624
# Preprocessed and saved sample 508/4624
# Preprocessed and saved sample 509/4624
# Preprocessed and saved sample 510/4624
# Preprocessed and saved sample 511/4624
# Preprocessed and saved sample 512/4624
# Preprocessed and saved sample 513/4624
# Preprocessed and saved sample 514/4624
# Preprocessed and saved sample 515/4624
# Preprocessed and saved sample 516/4624
# Preprocessed and saved sample 517/4624
# Preprocessed and saved sample 518/4624
# Preprocessed and saved sample 519/4624
# Preprocessed and saved sample 520/4624
# Preprocessed and saved sample 521/4624
# Preprocessed and saved sample 522/4624
# Preprocessed and saved sample 523/4624
# Preprocessed and saved sample 524/4624
# Preprocessed and saved sample 525/4624
# Preprocessed and saved sample 526/4624
# Preprocessed and saved sample 527/4624
# Preprocessed and saved sample 528/4624
# Preprocessed and saved sample 529/4624
# Preprocessed and saved sample 530/4624
# Preprocessed and saved sample 531/4624
# Preprocessed and saved sample 532/4624
# Preprocessed and saved sample 533/4624
# Preprocessed and saved sample 534/4624
# Preprocessed and saved sample 535/4624
# Preprocessed and saved sample 536/4624
# Preprocessed and saved sample 537/4624
# Preprocessed and saved sample 538/4624
# Preprocessed and saved sample 539/4624
# Preprocessed and saved sample 540/4624
# Preprocessed and saved sample 541/4624
# Preprocessed and saved sample 542/4624
# Preprocessed and saved sample 543/4624
# Preprocessed and saved sample 544/4624
# Preprocessed and saved sample 545/4624
# Preprocessed and saved sample 546/4624
# Preprocessed and saved sample 547/4624
# Preprocessed and saved sample 548/4624
# Preprocessed and saved sample 549/4624
# Preprocessed and saved sample 550/4624
# Preprocessed and saved sample 551/4624
# Preprocessed and saved sample 552/4624
# Preprocessed and saved sample 553/4624
# Preprocessed and saved sample 554/4624
# Preprocessed and saved sample 555/4624
# Preprocessed and saved sample 556/4624
# Preprocessed and saved sample 557/4624
# Preprocessed and saved sample 558/4624
# Preprocessed and saved sample 559/4624
# Preprocessed and saved sample 560/4624
# Preprocessed and saved sample 561/4624
# Preprocessed and saved sample 562/4624
# Preprocessed and saved sample 563/4624
# Preprocessed and saved sample 564/4624
# Preprocessed and saved sample 565/4624
# Preprocessed and saved sample 566/4624
# Preprocessed and saved sample 567/4624
# Preprocessed and saved sample 568/4624
# Preprocessed and saved sample 569/4624
# Preprocessed and saved sample 570/4624
# Preprocessed and saved sample 571/4624
# Preprocessed and saved sample 572/4624
# Preprocessed and saved sample 573/4624
# Preprocessed and saved sample 574/4624
# Preprocessed and saved sample 575/4624
# Preprocessed and saved sample 576/4624
# Preprocessed and saved sample 577/4624
# Preprocessed and saved sample 578/4624
# Preprocessed and saved sample 579/4624
# Preprocessed and saved sample 580/4624
# Preprocessed and saved sample 581/4624
# Preprocessed and saved sample 582/4624
# Preprocessed and saved sample 583/4624
# Preprocessed and saved sample 584/4624
# Preprocessed and saved sample 585/4624
# Preprocessed and saved sample 586/4624
# Preprocessed and saved sample 587/4624
# Preprocessed and saved sample 588/4624
# Preprocessed and saved sample 589/4624
# Preprocessed and saved sample 590/4624
# Preprocessed and saved sample 591/4624
# Preprocessed and saved sample 592/4624
# Preprocessed and saved sample 593/4624
# Preprocessed and saved sample 594/4624
# Preprocessed and saved sample 595/4624
# Preprocessed and saved sample 596/4624
# Preprocessed and saved sample 597/4624
# Preprocessed and saved sample 598/4624
# Preprocessed and saved sample 599/4624
# Preprocessed and saved sample 600/4624
# Preprocessed and saved sample 601/4624
# Preprocessed and saved sample 602/4624
# Preprocessed and saved sample 603/4624
# Preprocessed and saved sample 604/4624
# Preprocessed and saved sample 605/4624
# Preprocessed and saved sample 606/4624
# Preprocessed and saved sample 607/4624
# Preprocessed and saved sample 608/4624
# Preprocessed and saved sample 609/4624
# Preprocessed and saved sample 610/4624
# Preprocessed and saved sample 611/4624
# Preprocessed and saved sample 612/4624
# Preprocessed and saved sample 613/4624
# Preprocessed and saved sample 614/4624
# Preprocessed and saved sample 615/4624
# Preprocessed and saved sample 616/4624
# Preprocessed and saved sample 617/4624
# Preprocessed and saved sample 618/4624
# Preprocessed and saved sample 619/4624
# Preprocessed and saved sample 620/4624
# Preprocessed and saved sample 621/4624
# Preprocessed and saved sample 622/4624
# Preprocessed and saved sample 623/4624
# Preprocessed and saved sample 624/4624
# Preprocessed and saved sample 625/4624
# Preprocessed and saved sample 626/4624
# Preprocessed and saved sample 627/4624
# Preprocessed and saved sample 628/4624
# Preprocessed and saved sample 629/4624
# Preprocessed and saved sample 630/4624
# Preprocessed and saved sample 631/4624
# Preprocessed and saved sample 632/4624
# Preprocessed and saved sample 633/4624
# Preprocessed and saved sample 634/4624
# Preprocessed and saved sample 635/4624
# Preprocessed and saved sample 636/4624
# Preprocessed and saved sample 637/4624
# Preprocessed and saved sample 638/4624
# Preprocessed and saved sample 639/4624
# Preprocessed and saved sample 640/4624
# Preprocessed and saved sample 641/4624
# Preprocessed and saved sample 642/4624
# Preprocessed and saved sample 643/4624
# Preprocessed and saved sample 644/4624
# Preprocessed and saved sample 645/4624
# Preprocessed and saved sample 646/4624
# Preprocessed and saved sample 647/4624
# Preprocessed and saved sample 648/4624
# Preprocessed and saved sample 649/4624
# Preprocessed and saved sample 650/4624
# Preprocessed and saved sample 651/4624
# Preprocessed and saved sample 652/4624
# Preprocessed and saved sample 653/4624
# Preprocessed and saved sample 654/4624
# Preprocessed and saved sample 655/4624
# Preprocessed and saved sample 656/4624
# Preprocessed and saved sample 657/4624
# Preprocessed and saved sample 658/4624
# Preprocessed and saved sample 659/4624
# Preprocessed and saved sample 660/4624
# Preprocessed and saved sample 661/4624
# Preprocessed and saved sample 662/4624
# Preprocessed and saved sample 663/4624
# Preprocessed and saved sample 664/4624
# Preprocessed and saved sample 665/4624
# Preprocessed and saved sample 666/4624
# Preprocessed and saved sample 667/4624
# Preprocessed and saved sample 668/4624
# Preprocessed and saved sample 669/4624
# Preprocessed and saved sample 670/4624
# Preprocessed and saved sample 671/4624
# Preprocessed and saved sample 672/4624
# Preprocessed and saved sample 673/4624
# Preprocessed and saved sample 674/4624
# Preprocessed and saved sample 675/4624
# Preprocessed and saved sample 676/4624
# Preprocessed and saved sample 677/4624
# Preprocessed and saved sample 678/4624
# Preprocessed and saved sample 679/4624
# Preprocessed and saved sample 680/4624
# Preprocessed and saved sample 681/4624
# Preprocessed and saved sample 682/4624
# Preprocessed and saved sample 683/4624
# Preprocessed and saved sample 684/4624
# Preprocessed and saved sample 685/4624
# Preprocessed and saved sample 686/4624
# Preprocessed and saved sample 687/4624
# Preprocessed and saved sample 688/4624
# Preprocessed and saved sample 689/4624
# Preprocessed and saved sample 690/4624
# Preprocessed and saved sample 691/4624
# Preprocessed and saved sample 692/4624
# Preprocessed and saved sample 693/4624
# Preprocessed and saved sample 694/4624
# Preprocessed and saved sample 695/4624
# Preprocessed and saved sample 696/4624
# Preprocessed and saved sample 697/4624
# Preprocessed and saved sample 698/4624
# Preprocessed and saved sample 699/4624
# Preprocessed and saved sample 700/4624
# Preprocessed and saved sample 701/4624
# Preprocessed and saved sample 702/4624
# Preprocessed and saved sample 703/4624
# Preprocessed and saved sample 704/4624
# Preprocessed and saved sample 705/4624
# Preprocessed and saved sample 706/4624
# Preprocessed and saved sample 707/4624
# Preprocessed and saved sample 708/4624
# Preprocessed and saved sample 709/4624
# Preprocessed and saved sample 710/4624
# Preprocessed and saved sample 711/4624
# Preprocessed and saved sample 712/4624
# Preprocessed and saved sample 713/4624
# Preprocessed and saved sample 714/4624
# Preprocessed and saved sample 715/4624
# Preprocessed and saved sample 716/4624
# Preprocessed and saved sample 717/4624
# Preprocessed and saved sample 718/4624
# Preprocessed and saved sample 719/4624
# Preprocessed and saved sample 720/4624
# Preprocessed and saved sample 721/4624
# Preprocessed and saved sample 722/4624
# Preprocessed and saved sample 723/4624
# Preprocessed and saved sample 724/4624
# Preprocessed and saved sample 725/4624
# Preprocessed and saved sample 726/4624
# Preprocessed and saved sample 727/4624
# Preprocessed and saved sample 728/4624
# Preprocessed and saved sample 729/4624
# Preprocessed and saved sample 730/4624
# Preprocessed and saved sample 731/4624
# Preprocessed and saved sample 732/4624
# Preprocessed and saved sample 733/4624
# Preprocessed and saved sample 734/4624
# Preprocessed and saved sample 735/4624
# Preprocessed and saved sample 736/4624
# Preprocessed and saved sample 737/4624
# Preprocessed and saved sample 738/4624
# Preprocessed and saved sample 739/4624
# Preprocessed and saved sample 740/4624
# Preprocessed and saved sample 741/4624
# Preprocessed and saved sample 742/4624
# Preprocessed and saved sample 743/4624
# Preprocessed and saved sample 744/4624
# Preprocessed and saved sample 745/4624
# Preprocessed and saved sample 746/4624
# Preprocessed and saved sample 747/4624
# Preprocessed and saved sample 748/4624
# Preprocessed and saved sample 749/4624
# Preprocessed and saved sample 750/4624
# Preprocessed and saved sample 751/4624
# Preprocessed and saved sample 752/4624
# Preprocessed and saved sample 753/4624
# Preprocessed and saved sample 754/4624
# Preprocessed and saved sample 755/4624
# Preprocessed and saved sample 756/4624
# Preprocessed and saved sample 757/4624
# Preprocessed and saved sample 758/4624
# Preprocessed and saved sample 759/4624
# Preprocessed and saved sample 760/4624
# Preprocessed and saved sample 761/4624
# Preprocessed and saved sample 762/4624
# Preprocessed and saved sample 763/4624
# Preprocessed and saved sample 764/4624
# Preprocessed and saved sample 765/4624
# Preprocessed and saved sample 766/4624
# Preprocessed and saved sample 767/4624
# Preprocessed and saved sample 768/4624
# Preprocessed and saved sample 769/4624
# Preprocessed and saved sample 770/4624
# Preprocessed and saved sample 771/4624
# Preprocessed and saved sample 772/4624
# Preprocessed and saved sample 773/4624
# Preprocessed and saved sample 774/4624
# Preprocessed and saved sample 775/4624
# Preprocessed and saved sample 776/4624
# Preprocessed and saved sample 777/4624
# Preprocessed and saved sample 778/4624
# Preprocessed and saved sample 779/4624
# Preprocessed and saved sample 780/4624
# Preprocessed and saved sample 781/4624
# Preprocessed and saved sample 782/4624
# Preprocessed and saved sample 783/4624
# Preprocessed and saved sample 784/4624
# Preprocessed and saved sample 785/4624
# Preprocessed and saved sample 786/4624
# Preprocessed and saved sample 787/4624
# Preprocessed and saved sample 788/4624
# Preprocessed and saved sample 789/4624
# Preprocessed and saved sample 790/4624
# Preprocessed and saved sample 791/4624
# Preprocessed and saved sample 792/4624
# Preprocessed and saved sample 793/4624
# Preprocessed and saved sample 794/4624
# Preprocessed and saved sample 795/4624
# Preprocessed and saved sample 796/4624
# Preprocessed and saved sample 797/4624
# Preprocessed and saved sample 798/4624
# Preprocessed and saved sample 799/4624
# Preprocessed and saved sample 800/4624
# Preprocessed and saved sample 801/4624
# Preprocessed and saved sample 802/4624
# Preprocessed and saved sample 803/4624
# Preprocessed and saved sample 804/4624
# Preprocessed and saved sample 805/4624
# Preprocessed and saved sample 806/4624
# Preprocessed and saved sample 807/4624
# Preprocessed and saved sample 808/4624
# Preprocessed and saved sample 809/4624
# Preprocessed and saved sample 810/4624
# Preprocessed and saved sample 811/4624
# Preprocessed and saved sample 812/4624
# Preprocessed and saved sample 813/4624
# Preprocessed and saved sample 814/4624
# Preprocessed and saved sample 815/4624
# Preprocessed and saved sample 816/4624
# Preprocessed and saved sample 817/4624
# Preprocessed and saved sample 818/4624
# Preprocessed and saved sample 819/4624
# Preprocessed and saved sample 820/4624
# Preprocessed and saved sample 821/4624
# Preprocessed and saved sample 822/4624
# Preprocessed and saved sample 823/4624
# Preprocessed and saved sample 824/4624
# Preprocessed and saved sample 825/4624
# Preprocessed and saved sample 826/4624
# Preprocessed and saved sample 827/4624
# Preprocessed and saved sample 828/4624
# Preprocessed and saved sample 829/4624
# Preprocessed and saved sample 830/4624
# Preprocessed and saved sample 831/4624
# Preprocessed and saved sample 832/4624
# Preprocessed and saved sample 833/4624
# Preprocessed and saved sample 834/4624
# Preprocessed and saved sample 835/4624
# Preprocessed and saved sample 836/4624
# Preprocessed and saved sample 837/4624
# Preprocessed and saved sample 838/4624
# Preprocessed and saved sample 839/4624
# Preprocessed and saved sample 840/4624
# Preprocessed and saved sample 841/4624
# Preprocessed and saved sample 842/4624
# Preprocessed and saved sample 843/4624
# Preprocessed and saved sample 844/4624
# Preprocessed and saved sample 845/4624
# Preprocessed and saved sample 846/4624
# Preprocessed and saved sample 847/4624
# Preprocessed and saved sample 848/4624
# Preprocessed and saved sample 849/4624
# Preprocessed and saved sample 850/4624
# Preprocessed and saved sample 851/4624
# Preprocessed and saved sample 852/4624
# Preprocessed and saved sample 853/4624
# Preprocessed and saved sample 854/4624
# Preprocessed and saved sample 855/4624
# Preprocessed and saved sample 856/4624
# Preprocessed and saved sample 857/4624
# Preprocessed and saved sample 858/4624
# Preprocessed and saved sample 859/4624
# Preprocessed and saved sample 860/4624
# Preprocessed and saved sample 861/4624
# Preprocessed and saved sample 862/4624
# Preprocessed and saved sample 863/4624
# Preprocessed and saved sample 864/4624
# Preprocessed and saved sample 865/4624
# Preprocessed and saved sample 866/4624
# Preprocessed and saved sample 867/4624
# Preprocessed and saved sample 868/4624
# Preprocessed and saved sample 869/4624
# Preprocessed and saved sample 870/4624
# Preprocessed and saved sample 871/4624
# Preprocessed and saved sample 872/4624
# Preprocessed and saved sample 873/4624
# Preprocessed and saved sample 874/4624
# Preprocessed and saved sample 875/4624
# Preprocessed and saved sample 876/4624
# Preprocessed and saved sample 877/4624
# Preprocessed and saved sample 878/4624
# Preprocessed and saved sample 879/4624
# Preprocessed and saved sample 880/4624
# Preprocessed and saved sample 881/4624
# Preprocessed and saved sample 882/4624
# Preprocessed and saved sample 883/4624
# Preprocessed and saved sample 884/4624
# Preprocessed and saved sample 885/4624
# Preprocessed and saved sample 886/4624
# Preprocessed and saved sample 887/4624
# Preprocessed and saved sample 888/4624
# Preprocessed and saved sample 889/4624
# Preprocessed and saved sample 890/4624
# Preprocessed and saved sample 891/4624
# Preprocessed and saved sample 892/4624
# Preprocessed and saved sample 893/4624
# Preprocessed and saved sample 894/4624
# Preprocessed and saved sample 895/4624
# Preprocessed and saved sample 896/4624
# Preprocessed and saved sample 897/4624
# Preprocessed and saved sample 898/4624
# Preprocessed and saved sample 899/4624
# Preprocessed and saved sample 900/4624
# Preprocessed and saved sample 901/4624
# Preprocessed and saved sample 902/4624
# Preprocessed and saved sample 903/4624
# Preprocessed and saved sample 904/4624
# Preprocessed and saved sample 905/4624
# Preprocessed and saved sample 906/4624
# Preprocessed and saved sample 907/4624
# Preprocessed and saved sample 908/4624
# Preprocessed and saved sample 909/4624
# Preprocessed and saved sample 910/4624
# Preprocessed and saved sample 911/4624
# Preprocessed and saved sample 912/4624
# Preprocessed and saved sample 913/4624
# Preprocessed and saved sample 914/4624
# Preprocessed and saved sample 915/4624
# Preprocessed and saved sample 916/4624
# Preprocessed and saved sample 917/4624
# Preprocessed and saved sample 918/4624
# Preprocessed and saved sample 919/4624
# Preprocessed and saved sample 920/4624
# Preprocessed and saved sample 921/4624
# Preprocessed and saved sample 922/4624
# Preprocessed and saved sample 923/4624
# Preprocessed and saved sample 924/4624
# Preprocessed and saved sample 925/4624
# Preprocessed and saved sample 926/4624
# Preprocessed and saved sample 927/4624
# Preprocessed and saved sample 928/4624
# Preprocessed and saved sample 929/4624
# Preprocessed and saved sample 930/4624
# Preprocessed and saved sample 931/4624
# Preprocessed and saved sample 932/4624
# Preprocessed and saved sample 933/4624
# Preprocessed and saved sample 934/4624
# Preprocessed and saved sample 935/4624
# Preprocessed and saved sample 936/4624
# Preprocessed and saved sample 937/4624
# Preprocessed and saved sample 938/4624
# Preprocessed and saved sample 939/4624
# Preprocessed and saved sample 940/4624
# Preprocessed and saved sample 941/4624
# Preprocessed and saved sample 942/4624
# Preprocessed and saved sample 943/4624
# Preprocessed and saved sample 944/4624
# Preprocessed and saved sample 945/4624
# Preprocessed and saved sample 946/4624
# Preprocessed and saved sample 947/4624
# Preprocessed and saved sample 948/4624
# Preprocessed and saved sample 949/4624
# Preprocessed and saved sample 950/4624
# Preprocessed and saved sample 951/4624
# Preprocessed and saved sample 952/4624
# Preprocessed and saved sample 953/4624
# Preprocessed and saved sample 954/4624
# Preprocessed and saved sample 955/4624
# Preprocessed and saved sample 956/4624
# Preprocessed and saved sample 957/4624
# Preprocessed and saved sample 958/4624
# Preprocessed and saved sample 959/4624
# Preprocessed and saved sample 960/4624
# Preprocessed and saved sample 961/4624
# Preprocessed and saved sample 962/4624
# Preprocessed and saved sample 963/4624
# Preprocessed and saved sample 964/4624
# Preprocessed and saved sample 965/4624
# Preprocessed and saved sample 966/4624
# Preprocessed and saved sample 967/4624
# Preprocessed and saved sample 968/4624
# Preprocessed and saved sample 969/4624
# Preprocessed and saved sample 970/4624
# Preprocessed and saved sample 971/4624
# Preprocessed and saved sample 972/4624
# Preprocessed and saved sample 973/4624
# Preprocessed and saved sample 974/4624
# Preprocessed and saved sample 975/4624
# Preprocessed and saved sample 976/4624
# Preprocessed and saved sample 977/4624
# Preprocessed and saved sample 978/4624
# Preprocessed and saved sample 979/4624
# Preprocessed and saved sample 980/4624
# Preprocessed and saved sample 981/4624
# Preprocessed and saved sample 982/4624
# Preprocessed and saved sample 983/4624
# Preprocessed and saved sample 984/4624
# Preprocessed and saved sample 985/4624
# Preprocessed and saved sample 986/4624
# Preprocessed and saved sample 987/4624
# Preprocessed and saved sample 988/4624
# Preprocessed and saved sample 989/4624
# Preprocessed and saved sample 990/4624
# Preprocessed and saved sample 991/4624
# Preprocessed and saved sample 992/4624
# Preprocessed and saved sample 993/4624
# Preprocessed and saved sample 994/4624
# Preprocessed and saved sample 995/4624
# Preprocessed and saved sample 996/4624
# Preprocessed and saved sample 997/4624
# Preprocessed and saved sample 998/4624
# Preprocessed and saved sample 999/4624
# Preprocessed and saved sample 1000/4624
# Preprocessed and saved sample 1001/4624
# Preprocessed and saved sample 1002/4624
# Preprocessed and saved sample 1003/4624
# Preprocessed and saved sample 1004/4624
# Preprocessed and saved sample 1005/4624
# Preprocessed and saved sample 1006/4624
# Preprocessed and saved sample 1007/4624
# Preprocessed and saved sample 1008/4624
# Preprocessed and saved sample 1009/4624
# Preprocessed and saved sample 1010/4624
# Preprocessed and saved sample 1011/4624
# Preprocessed and saved sample 1012/4624
# Preprocessed and saved sample 1013/4624
# Preprocessed and saved sample 1014/4624
# Preprocessed and saved sample 1015/4624
# Preprocessed and saved sample 1016/4624
# Preprocessed and saved sample 1017/4624
# Preprocessed and saved sample 1018/4624
# Preprocessed and saved sample 1019/4624
# Preprocessed and saved sample 1020/4624
# Preprocessed and saved sample 1021/4624
# Preprocessed and saved sample 1022/4624
# Preprocessed and saved sample 1023/4624
# Preprocessed and saved sample 1024/4624
# Preprocessed and saved sample 1025/4624
# Preprocessed and saved sample 1026/4624
# Preprocessed and saved sample 1027/4624
# Preprocessed and saved sample 1028/4624
# Preprocessed and saved sample 1029/4624
# Preprocessed and saved sample 1030/4624
# Preprocessed and saved sample 1031/4624
# Preprocessed and saved sample 1032/4624
# Preprocessed and saved sample 1033/4624
# Preprocessed and saved sample 1034/4624
# Preprocessed and saved sample 1035/4624
# Preprocessed and saved sample 1036/4624
# Preprocessed and saved sample 1037/4624
# Preprocessed and saved sample 1038/4624
# Preprocessed and saved sample 1039/4624
# Preprocessed and saved sample 1040/4624
# Preprocessed and saved sample 1041/4624
# Preprocessed and saved sample 1042/4624
# Preprocessed and saved sample 1043/4624
# Preprocessed and saved sample 1044/4624
# Preprocessed and saved sample 1045/4624
# Preprocessed and saved sample 1046/4624
# Preprocessed and saved sample 1047/4624
# Preprocessed and saved sample 1048/4624
# Preprocessed and saved sample 1049/4624
# Preprocessed and saved sample 1050/4624
# Preprocessed and saved sample 1051/4624
# Preprocessed and saved sample 1052/4624
# Preprocessed and saved sample 1053/4624
# Preprocessed and saved sample 1054/4624
# Preprocessed and saved sample 1055/4624
# Preprocessed and saved sample 1056/4624
# Preprocessed and saved sample 1057/4624
# Preprocessed and saved sample 1058/4624
# Preprocessed and saved sample 1059/4624
# Preprocessed and saved sample 1060/4624
# Preprocessed and saved sample 1061/4624
# Preprocessed and saved sample 1062/4624
# Preprocessed and saved sample 1063/4624
# Preprocessed and saved sample 1064/4624
# Preprocessed and saved sample 1065/4624
# Preprocessed and saved sample 1066/4624
# Preprocessed and saved sample 1067/4624
# Preprocessed and saved sample 1068/4624
# Preprocessed and saved sample 1069/4624
# Preprocessed and saved sample 1070/4624
# Preprocessed and saved sample 1071/4624
# Preprocessed and saved sample 1072/4624
# Preprocessed and saved sample 1073/4624
# Preprocessed and saved sample 1074/4624
# Preprocessed and saved sample 1075/4624
# Preprocessed and saved sample 1076/4624
# Preprocessed and saved sample 1077/4624
# Preprocessed and saved sample 1078/4624
# Preprocessed and saved sample 1079/4624
# Preprocessed and saved sample 1080/4624
# Preprocessed and saved sample 1081/4624
# Preprocessed and saved sample 1082/4624
# Preprocessed and saved sample 1083/4624
# Preprocessed and saved sample 1084/4624
# Preprocessed and saved sample 1085/4624
# Preprocessed and saved sample 1086/4624
# Preprocessed and saved sample 1087/4624
# Preprocessed and saved sample 1088/4624
# Preprocessed and saved sample 1089/4624
# Preprocessed and saved sample 1090/4624
# Preprocessed and saved sample 1091/4624
# Preprocessed and saved sample 1092/4624
# Preprocessed and saved sample 1093/4624
# Preprocessed and saved sample 1094/4624
# Preprocessed and saved sample 1095/4624
# Preprocessed and saved sample 1096/4624
# Preprocessed and saved sample 1097/4624
# Preprocessed and saved sample 1098/4624
# Preprocessed and saved sample 1099/4624
# Preprocessed and saved sample 1100/4624
# Preprocessed and saved sample 1101/4624
# Preprocessed and saved sample 1102/4624
# Preprocessed and saved sample 1103/4624
# Preprocessed and saved sample 1104/4624
# Preprocessed and saved sample 1105/4624
# Preprocessed and saved sample 1106/4624
# Preprocessed and saved sample 1107/4624
# Preprocessed and saved sample 1108/4624
# Preprocessed and saved sample 1109/4624
# Preprocessed and saved sample 1110/4624
# Preprocessed and saved sample 1111/4624
# Preprocessed and saved sample 1112/4624
# Preprocessed and saved sample 1113/4624
# Preprocessed and saved sample 1114/4624
# Preprocessed and saved sample 1115/4624
# Preprocessed and saved sample 1116/4624
# Preprocessed and saved sample 1117/4624
# Preprocessed and saved sample 1118/4624
# Preprocessed and saved sample 1119/4624
# Preprocessed and saved sample 1120/4624
# Preprocessed and saved sample 1121/4624
# Preprocessed and saved sample 1122/4624
# Preprocessed and saved sample 1123/4624
# Preprocessed and saved sample 1124/4624
# Preprocessed and saved sample 1125/4624
# Preprocessed and saved sample 1126/4624
# Preprocessed and saved sample 1127/4624
# Preprocessed and saved sample 1128/4624
# Preprocessed and saved sample 1129/4624
# Preprocessed and saved sample 1130/4624
# Preprocessed and saved sample 1131/4624
# Preprocessed and saved sample 1132/4624
# Preprocessed and saved sample 1133/4624
# Preprocessed and saved sample 1134/4624
# Preprocessed and saved sample 1135/4624
# Preprocessed and saved sample 1136/4624
# Preprocessed and saved sample 1137/4624
# Preprocessed and saved sample 1138/4624
# Preprocessed and saved sample 1139/4624
# Preprocessed and saved sample 1140/4624
# Preprocessed and saved sample 1141/4624
# Preprocessed and saved sample 1142/4624
# Preprocessed and saved sample 1143/4624
# Preprocessed and saved sample 1144/4624
# Preprocessed and saved sample 1145/4624
# Preprocessed and saved sample 1146/4624
# Preprocessed and saved sample 1147/4624
# Preprocessed and saved sample 1148/4624
# Preprocessed and saved sample 1149/4624
# Preprocessed and saved sample 1150/4624
# Preprocessed and saved sample 1151/4624
# Preprocessed and saved sample 1152/4624
# Preprocessed and saved sample 1153/4624
# Preprocessed and saved sample 1154/4624
# Preprocessed and saved sample 1155/4624
# Preprocessed and saved sample 1156/4624
# Preprocessed and saved sample 1157/4624
# Preprocessed and saved sample 1158/4624
# Preprocessed and saved sample 1159/4624
# Preprocessed and saved sample 1160/4624
# Preprocessed and saved sample 1161/4624
# Preprocessed and saved sample 1162/4624
# Preprocessed and saved sample 1163/4624
# Preprocessed and saved sample 1164/4624
# Preprocessed and saved sample 1165/4624
# Preprocessed and saved sample 1166/4624
# Preprocessed and saved sample 1167/4624
# Preprocessed and saved sample 1168/4624
# Preprocessed and saved sample 1169/4624
# Preprocessed and saved sample 1170/4624
# Preprocessed and saved sample 1171/4624
# Preprocessed and saved sample 1172/4624
# Preprocessed and saved sample 1173/4624
# Preprocessed and saved sample 1174/4624
# Preprocessed and saved sample 1175/4624
# Preprocessed and saved sample 1176/4624
# Preprocessed and saved sample 1177/4624
# Preprocessed and saved sample 1178/4624
# Preprocessed and saved sample 1179/4624
# Preprocessed and saved sample 1180/4624
# Preprocessed and saved sample 1181/4624
# Preprocessed and saved sample 1182/4624
# Preprocessed and saved sample 1183/4624
# Preprocessed and saved sample 1184/4624
# Preprocessed and saved sample 1185/4624
# Preprocessed and saved sample 1186/4624
# Preprocessed and saved sample 1187/4624
# Preprocessed and saved sample 1188/4624
# Preprocessed and saved sample 1189/4624
# Preprocessed and saved sample 1190/4624
# Preprocessed and saved sample 1191/4624
# Preprocessed and saved sample 1192/4624
# Preprocessed and saved sample 1193/4624
# Preprocessed and saved sample 1194/4624
# Preprocessed and saved sample 1195/4624
# Preprocessed and saved sample 1196/4624
# Preprocessed and saved sample 1197/4624
# Preprocessed and saved sample 1198/4624
# Preprocessed and saved sample 1199/4624
# Preprocessed and saved sample 1200/4624
# Preprocessed and saved sample 1201/4624
# Preprocessed and saved sample 1202/4624
# Preprocessed and saved sample 1203/4624
# Preprocessed and saved sample 1204/4624
# Preprocessed and saved sample 1205/4624
# Preprocessed and saved sample 1206/4624
# Preprocessed and saved sample 1207/4624
# Preprocessed and saved sample 1208/4624
# Preprocessed and saved sample 1209/4624
# Preprocessed and saved sample 1210/4624
# Preprocessed and saved sample 1211/4624
# Preprocessed and saved sample 1212/4624
# Preprocessed and saved sample 1213/4624
# Preprocessed and saved sample 1214/4624
# Preprocessed and saved sample 1215/4624
# Preprocessed and saved sample 1216/4624
# Preprocessed and saved sample 1217/4624
# Preprocessed and saved sample 1218/4624
# Preprocessed and saved sample 1219/4624
# Preprocessed and saved sample 1220/4624
# Preprocessed and saved sample 1221/4624
# Preprocessed and saved sample 1222/4624
# Preprocessed and saved sample 1223/4624
# Preprocessed and saved sample 1224/4624
# Preprocessed and saved sample 1225/4624
# Preprocessed and saved sample 1226/4624
# Preprocessed and saved sample 1227/4624
# ...
# Preprocessed and saved sample 164/583
# Preprocessed and saved sample 165/583
# Preprocessed and saved sample 166/583
# Preprocessed and saved sample 167/583
# Preprocessed and saved sample 168/583
# Preprocessed and saved sample 169/583
# Preprocessed and saved sample 170/583
# Preprocessed and saved sample 171/583
# Preprocessed and saved sample 172/583
# Preprocessed and saved sample 173/583
# Preprocessed and saved sample 174/583
# Preprocessed and saved sample 175/583
# Preprocessed and saved sample 176/583
# Preprocessed and saved sample 177/583
# Preprocessed and saved sample 178/583
# Preprocessed and saved sample 179/583
# Preprocessed and saved sample 180/583
# Preprocessed and saved sample 181/583
# Preprocessed and saved sample 182/583
# Preprocessed and saved sample 183/583
# Preprocessed and saved sample 184/583
# Preprocessed and saved sample 185/583
# Preprocessed and saved sample 186/583
# Preprocessed and saved sample 187/583
# Preprocessed and saved sample 188/583
# Preprocessed and saved sample 189/583
# Preprocessed and saved sample 190/583
# Preprocessed and saved sample 191/583
# Preprocessed and saved sample 192/583
# Preprocessed and saved sample 193/583
# Preprocessed and saved sample 194/583
# Preprocessed and saved sample 195/583
# Preprocessed and saved sample 196/583
# Preprocessed and saved sample 197/583
# Preprocessed and saved sample 198/583
# Preprocessed and saved sample 199/583
# Preprocessed and saved sample 200/583
# Preprocessed and saved sample 201/583
# Preprocessed and saved sample 202/583
# Preprocessed and saved sample 203/583
# Preprocessed and saved sample 204/583
# Preprocessed and saved sample 205/583
# Preprocessed and saved sample 206/583
# Preprocessed and saved sample 207/583
# Preprocessed and saved sample 208/583
# Preprocessed and saved sample 209/583
# Preprocessed and saved sample 210/583
# Preprocessed and saved sample 211/583
# Preprocessed and saved sample 212/583
# Preprocessed and saved sample 213/583
# Preprocessed and saved sample 214/583
# Preprocessed and saved sample 215/583
# Preprocessed and saved sample 216/583
# Preprocessed and saved sample 217/583
# Preprocessed and saved sample 218/583
# Preprocessed and saved sample 219/583
# Preprocessed and saved sample 220/583
# Preprocessed and saved sample 221/583
# Preprocessed and saved sample 222/583
# Preprocessed and saved sample 223/583
# Preprocessed and saved sample 224/583
# Preprocessed and saved sample 225/583
# Preprocessed and saved sample 226/583
# Preprocessed and saved sample 227/583
# Preprocessed and saved sample 228/583
# Preprocessed and saved sample 229/583
# Preprocessed and saved sample 230/583
# Preprocessed and saved sample 231/583
# Preprocessed and saved sample 232/583
# Preprocessed and saved sample 233/583
# Preprocessed and saved sample 234/583
# Preprocessed and saved sample 235/583
# Preprocessed and saved sample 236/583
# Preprocessed and saved sample 237/583
# Preprocessed and saved sample 238/583
# Preprocessed and saved sample 239/583
# Preprocessed and saved sample 240/583
# Preprocessed and saved sample 241/583
# Preprocessed and saved sample 242/583
# Preprocessed and saved sample 243/583
# Preprocessed and saved sample 244/583
# Preprocessed and saved sample 245/583
# Preprocessed and saved sample 246/583
# Preprocessed and saved sample 247/583
# Preprocessed and saved sample 248/583
# Preprocessed and saved sample 249/583
# Preprocessed and saved sample 250/583
# Preprocessed and saved sample 251/583
# Preprocessed and saved sample 252/583
# Preprocessed and saved sample 253/583
# Preprocessed and saved sample 254/583
# Preprocessed and saved sample 255/583
# Preprocessed and saved sample 256/583
# Preprocessed and saved sample 257/583
# Preprocessed and saved sample 258/583
# Preprocessed and saved sample 259/583
# Preprocessed and saved sample 260/583
# Preprocessed and saved sample 261/583
# Preprocessed and saved sample 262/583
# Preprocessed and saved sample 263/583
# Preprocessed and saved sample 264/583
# Preprocessed and saved sample 265/583
# Preprocessed and saved sample 266/583
# Preprocessed and saved sample 267/583
# Preprocessed and saved sample 268/583
# Preprocessed and saved sample 269/583
# Preprocessed and saved sample 270/583
# Preprocessed and saved sample 271/583
# Preprocessed and saved sample 272/583
# Preprocessed and saved sample 273/583
# Preprocessed and saved sample 274/583
# Preprocessed and saved sample 275/583
# Preprocessed and saved sample 276/583
# Preprocessed and saved sample 277/583
# Preprocessed and saved sample 278/583
# Preprocessed and saved sample 279/583
# Preprocessed and saved sample 280/583
# Preprocessed and saved sample 281/583
# Preprocessed and saved sample 282/583
# Preprocessed and saved sample 283/583
# Preprocessed and saved sample 284/583
# Preprocessed and saved sample 285/583
# Preprocessed and saved sample 286/583
# Preprocessed and saved sample 287/583
# Preprocessed and saved sample 288/583
# Preprocessed and saved sample 289/583
# Preprocessed and saved sample 290/583
# Preprocessed and saved sample 291/583
# Preprocessed and saved sample 292/583
# Preprocessed and saved sample 293/583
# Preprocessed and saved sample 294/583
# Preprocessed and saved sample 295/583
# Preprocessed and saved sample 296/583
# Preprocessed and saved sample 297/583
# Preprocessed and saved sample 298/583
# Preprocessed and saved sample 299/583
# Preprocessed and saved sample 300/583
# Preprocessed and saved sample 301/583
# Preprocessed and saved sample 302/583
# Preprocessed and saved sample 303/583
# Preprocessed and saved sample 304/583
# Preprocessed and saved sample 305/583
# Preprocessed and saved sample 306/583
# Preprocessed and saved sample 307/583
# Preprocessed and saved sample 308/583
# Preprocessed and saved sample 309/583
# Preprocessed and saved sample 310/583
# Preprocessed and saved sample 311/583
# Preprocessed and saved sample 312/583
# Preprocessed and saved sample 313/583
# Preprocessed and saved sample 314/583
# Preprocessed and saved sample 315/583
# Preprocessed and saved sample 316/583
# Preprocessed and saved sample 317/583
# Preprocessed and saved sample 318/583
# Preprocessed and saved sample 319/583
# Preprocessed and saved sample 320/583
# Preprocessed and saved sample 321/583
# Preprocessed and saved sample 322/583
# Preprocessed and saved sample 323/583
# Preprocessed and saved sample 324/583
# Preprocessed and saved sample 325/583
# Preprocessed and saved sample 326/583
# Preprocessed and saved sample 327/583
# Preprocessed and saved sample 328/583
# Preprocessed and saved sample 329/583
# Preprocessed and saved sample 330/583
# Preprocessed and saved sample 331/583
# Preprocessed and saved sample 332/583
# Preprocessed and saved sample 333/583
# Preprocessed and saved sample 334/583
# Preprocessed and saved sample 335/583
# Preprocessed and saved sample 336/583
# Preprocessed and saved sample 337/583
# Preprocessed and saved sample 338/583
# Preprocessed and saved sample 339/583
# Preprocessed and saved sample 340/583
# Preprocessed and saved sample 341/583
# Preprocessed and saved sample 342/583
# Preprocessed and saved sample 343/583
# Preprocessed and saved sample 344/583
# Preprocessed and saved sample 345/583
# Preprocessed and saved sample 346/583
# Preprocessed and saved sample 347/583
# Preprocessed and saved sample 348/583
# Preprocessed and saved sample 349/583
# Preprocessed and saved sample 350/583
# Preprocessed and saved sample 351/583
# Preprocessed and saved sample 352/583
# Preprocessed and saved sample 353/583
# Preprocessed and saved sample 354/583
# Preprocessed and saved sample 355/583
# Preprocessed and saved sample 356/583
# Preprocessed and saved sample 357/583
# Preprocessed and saved sample 358/583
# Preprocessed and saved sample 359/583
# Preprocessed and saved sample 360/583
# Preprocessed and saved sample 361/583
# Preprocessed and saved sample 362/583
# Preprocessed and saved sample 363/583
# Preprocessed and saved sample 364/583
# Preprocessed and saved sample 365/583
# Preprocessed and saved sample 366/583
# Preprocessed and saved sample 367/583
# Preprocessed and saved sample 368/583
# Preprocessed and saved sample 369/583
# Preprocessed and saved sample 370/583
# Preprocessed and saved sample 371/583
# Preprocessed and saved sample 372/583
# Preprocessed and saved sample 373/583
# Preprocessed and saved sample 374/583
# Preprocessed and saved sample 375/583
# Preprocessed and saved sample 376/583
# Preprocessed and saved sample 377/583
# Preprocessed and saved sample 378/583
# Preprocessed and saved sample 379/583
# Preprocessed and saved sample 380/583
# Preprocessed and saved sample 381/583
# Preprocessed and saved sample 382/583
# Preprocessed and saved sample 383/583
# Preprocessed and saved sample 384/583
# Preprocessed and saved sample 385/583
# Preprocessed and saved sample 386/583
# Preprocessed and saved sample 387/583
# Preprocessed and saved sample 388/583
# Preprocessed and saved sample 389/583
# Preprocessed and saved sample 390/583
# Preprocessed and saved sample 391/583
# Preprocessed and saved sample 392/583
# Preprocessed and saved sample 393/583
# Preprocessed and saved sample 394/583
# Preprocessed and saved sample 395/583
# Preprocessed and saved sample 396/583
# Preprocessed and saved sample 397/583
# Preprocessed and saved sample 398/583
# Preprocessed and saved sample 399/583
# Preprocessed and saved sample 400/583
# Preprocessed and saved sample 401/583
# Preprocessed and saved sample 402/583
# Preprocessed and saved sample 403/583
# Preprocessed and saved sample 404/583
# Preprocessed and saved sample 405/583
# Preprocessed and saved sample 406/583
# Preprocessed and saved sample 407/583
# Preprocessed and saved sample 408/583
# Preprocessed and saved sample 409/583
# Preprocessed and saved sample 410/583
# Preprocessed and saved sample 411/583
# Preprocessed and saved sample 412/583
# Preprocessed and saved sample 413/583
# Preprocessed and saved sample 414/583
# Preprocessed and saved sample 415/583
# Preprocessed and saved sample 416/583
# Preprocessed and saved sample 417/583
# Preprocessed and saved sample 418/583
# Preprocessed and saved sample 419/583
# Preprocessed and saved sample 420/583
# Preprocessed and saved sample 421/583
# Preprocessed and saved sample 422/583
# Preprocessed and saved sample 423/583
# Preprocessed and saved sample 424/583
# Preprocessed and saved sample 425/583
# Preprocessed and saved sample 426/583
# Preprocessed and saved sample 427/583
# Preprocessed and saved sample 428/583
# Preprocessed and saved sample 429/583
# Preprocessed and saved sample 430/583
# Preprocessed and saved sample 431/583
# Preprocessed and saved sample 432/583
# Preprocessed and saved sample 433/583
# Preprocessed and saved sample 434/583
# Preprocessed and saved sample 435/583
# Preprocessed and saved sample 436/583
# Preprocessed and saved sample 437/583
# Preprocessed and saved sample 438/583
# Preprocessed and saved sample 439/583
# Preprocessed and saved sample 440/583
# Preprocessed and saved sample 441/583
# Preprocessed and saved sample 442/583
# Preprocessed and saved sample 443/583
# Preprocessed and saved sample 444/583
# Preprocessed and saved sample 445/583
# Preprocessed and saved sample 446/583
# Preprocessed and saved sample 447/583
# Preprocessed and saved sample 448/583
# Preprocessed and saved sample 449/583
# Preprocessed and saved sample 450/583
# Preprocessed and saved sample 451/583
# Preprocessed and saved sample 452/583
# Preprocessed and saved sample 453/583
# Preprocessed and saved sample 454/583
# Preprocessed and saved sample 455/583
# Preprocessed and saved sample 456/583
# Preprocessed and saved sample 457/583
# Preprocessed and saved sample 458/583
# Preprocessed and saved sample 459/583
# Preprocessed and saved sample 460/583
# Preprocessed and saved sample 461/583
# Preprocessed and saved sample 462/583
# Preprocessed and saved sample 463/583
# Preprocessed and saved sample 464/583
# Preprocessed and saved sample 465/583
# Preprocessed and saved sample 466/583
# Preprocessed and saved sample 467/583
# Preprocessed and saved sample 468/583
# Preprocessed and saved sample 469/583
# Preprocessed and saved sample 470/583
# Preprocessed and saved sample 471/583
# Preprocessed and saved sample 472/583
# Preprocessed and saved sample 473/583
# Preprocessed and saved sample 474/583
# Preprocessed and saved sample 475/583
# Preprocessed and saved sample 476/583
# Preprocessed and saved sample 477/583
# Preprocessed and saved sample 478/583
# Preprocessed and saved sample 479/583
# Preprocessed and saved sample 480/583
# Preprocessed and saved sample 481/583
# Preprocessed and saved sample 482/583
# Preprocessed and saved sample 483/583
# Preprocessed and saved sample 484/583
# Preprocessed and saved sample 485/583
# Preprocessed and saved sample 486/583
# Preprocessed and saved sample 487/583
# Preprocessed and saved sample 488/583
# Preprocessed and saved sample 489/583
# Preprocessed and saved sample 490/583
# Preprocessed and saved sample 491/583
# Preprocessed and saved sample 492/583
# Preprocessed and saved sample 493/583
# Preprocessed and saved sample 494/583
# Preprocessed and saved sample 495/583
# Preprocessed and saved sample 496/583
# Preprocessed and saved sample 497/583
# Preprocessed and saved sample 498/583
# Preprocessed and saved sample 499/583
# Preprocessed and saved sample 500/583
# Preprocessed and saved sample 501/583
# Preprocessed and saved sample 502/583
# Preprocessed and saved sample 503/583
# Preprocessed and saved sample 504/583
# Preprocessed and saved sample 505/583
# Preprocessed and saved sample 506/583
# Preprocessed and saved sample 507/583
# Preprocessed and saved sample 508/583
# Preprocessed and saved sample 509/583
# Preprocessed and saved sample 510/583
# Preprocessed and saved sample 511/583
# Preprocessed and saved sample 512/583
# Preprocessed and saved sample 513/583
# Preprocessed and saved sample 514/583
# Preprocessed and saved sample 515/583
# Preprocessed and saved sample 516/583
# Preprocessed and saved sample 517/583
# Preprocessed and saved sample 518/583
# Preprocessed and saved sample 519/583
# Preprocessed and saved sample 520/583
# Preprocessed and saved sample 521/583
# Preprocessed and saved sample 522/583
# Preprocessed and saved sample 523/583
# Preprocessed and saved sample 524/583
# Preprocessed and saved sample 525/583
# Preprocessed and saved sample 526/583
# Preprocessed and saved sample 527/583
# Preprocessed and saved sample 528/583
# Preprocessed and saved sample 529/583
# Preprocessed and saved sample 530/583
# Preprocessed and saved sample 531/583
# Preprocessed and saved sample 532/583
# Preprocessed and saved sample 533/583
# Preprocessed and saved sample 534/583
# Preprocessed and saved sample 535/583
# Preprocessed and saved sample 536/583
# Preprocessed and saved sample 537/583
# Preprocessed and saved sample 538/583
# Preprocessed and saved sample 539/583
# Preprocessed and saved sample 540/583
# Preprocessed and saved sample 541/583
# Preprocessed and saved sample 542/583
# Preprocessed and saved sample 543/583
# Preprocessed and saved sample 544/583
# Preprocessed and saved sample 545/583
# Preprocessed and saved sample 546/583
# Preprocessed and saved sample 547/583
# Preprocessed and saved sample 548/583
# Preprocessed and saved sample 549/583
# Preprocessed and saved sample 550/583
# Preprocessed and saved sample 551/583
# Preprocessed and saved sample 552/583
# Preprocessed and saved sample 553/583
# Preprocessed and saved sample 554/583
# Preprocessed and saved sample 555/583
# Preprocessed and saved sample 556/583
# Preprocessed and saved sample 557/583
# Preprocessed and saved sample 558/583
# Preprocessed and saved sample 559/583
# Preprocessed and saved sample 560/583
# Preprocessed and saved sample 561/583
# Preprocessed and saved sample 562/583
# Preprocessed and saved sample 563/583
# Preprocessed and saved sample 564/583
# Preprocessed and saved sample 565/583
# Preprocessed and saved sample 566/583
# Preprocessed and saved sample 567/583
# Preprocessed and saved sample 568/583
# Preprocessed and saved sample 569/583
# Preprocessed and saved sample 570/583
# Preprocessed and saved sample 571/583
# Preprocessed and saved sample 572/583
# Preprocessed and saved sample 573/583
# Preprocessed and saved sample 574/583
# Preprocessed and saved sample 575/583
# Preprocessed and saved sample 576/583
# Preprocessed and saved sample 577/583
# Preprocessed and saved sample 578/583
# Preprocessed and saved sample 579/583
# Preprocessed and saved sample 580/583
# Preprocessed and saved sample 581/583
# Preprocessed and saved sample 582/583
# Preprocessed and saved sample 583/583
# Preprocessing complete!

# %%
# Directories for precomputed data
precomputed_dir = f'data/{history_len}_{n_x}_{n_y}'

# Build datasets from precomputed files
train_dataset = build_datasets_from_files(f'{precomputed_dir}/train')
val_dataset = build_datasets_from_files(f'{precomputed_dir}/val')
test_dataset = build_datasets_from_files(f'{precomputed_dir}/test')

# Build dataloaders
batch_size = 1024
train_loader = build_train_loader(train_dataset, batch_size=batch_size)
val_loader = build_val_loader(val_dataset, batch_size=batch_size)
test_loader = build_test_loader(test_dataset, batch_size=batch_size)

# %%
data_iter = iter(test_loader)
batch_data = next(data_iter)
edges = extract_edge_info(train_dataset)
# Out:
# c:\Users\luisi\Documents\Programming\Python\Football\xDiyo\football_dataset_xDiyoFire.py:1247: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(self.file_paths[idx])

# %%
class CreateEmbMLP(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=None, num_layers=1, dropout=0.0, bias=None):
        super().__init__()
        self.num_layers = num_layers
        if num_layers == 1:
            final_layer = nn.Linear(input_dim, output_dim)
            if bias is not None:
                # Expecting bias to be a tensor of shape (output_dim,)
                if bias.shape != final_layer.bias.shape:
                    raise ValueError(f"Bias tensor shape mismatch. Expected {final_layer.bias.shape}, got {bias.shape}")
                final_layer.bias.data.copy_(bias)
            self.layers = final_layer
        else:
            hidden_dim = hidden_dim if hidden_dim is not None else input_dim
            net = []
            # First layer
            net.append(nn.Linear(input_dim, hidden_dim))
            net.append(nn.ReLU())
            if dropout > 0:
                net.append(nn.Dropout(dropout))
            # Hidden layers
            for _ in range(num_layers - 2):
                net.append(nn.Linear(hidden_dim, hidden_dim))
                net.append(nn.ReLU())
                if dropout > 0:
                    net.append(nn.Dropout(dropout))
            # Final output layer
            final_layer = nn.Linear(hidden_dim, output_dim)
            if bias is not None:
                if bias.shape != final_layer.bias.shape:
                    raise ValueError(f"Bias tensor shape mismatch. Expected {final_layer.bias.shape}, got {bias.shape}")
                final_layer.bias.data.copy_(bias)
            net.append(final_layer)
            self.layers = nn.Sequential(*net)

    def forward(self, x):
        return self.layers(x)
    
class SimpleHeatmapCNN(nn.Module):
    def __init__(self, in_channels=1, output_dim=32):
        """
        A simple CNN to process small heatmaps.
        
        Args:
            in_channels (int): Number of channels in the input heatmap.
                            (For example, 1 if it's a grayscale heatmap.)
            output_dim (int): Dimension of the output hidden vector.
        """
        super(SimpleHeatmapCNN, self).__init__()
        # One convolutional layer with 8 filters and kernel size 3
        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=2, padding=1)
        self.bn1 = nn.BatchNorm2d(8)
        # Use average pooling (2x2) to reduce spatial dimensions.
        self.pool = nn.MaxPool2d(2)
        # Adaptive pooling ensures the output is 1x1 regardless of the input size.
        self.adaptive_pool = nn.AdaptiveMaxPool2d((8, 8))
        # Final fully connected layer to project the features to output_dim.
        self.fc = nn.Linear(8*8*8, output_dim)
    
    def forward(self, x):
        """
        Args:
            x: Input heatmap tensor with shape [batch_size, in_channels, H, W]
        Returns:
            A tensor of shape [batch_size, output_dim] summarizing the heatmap.
        """
        x = F.relu(self.bn1(self.conv1(x)))  # Convolution + BN + ReLU
        x = self.pool(x)                     # Reduce spatial dimensions
        x = self.adaptive_pool(x)            # Force output to 1x1 feature map
        x = x.view(x.size(0), -1)            # Flatten to [batch_size, 8]
        x = self.fc(x)                       # Project to output_dim
        return x

class HeatmapCNN(nn.Module):
    def __init__(self, in_channels=1, output_dim=64):
        """
        Args:
            in_channels (int): Number of channels in the input heatmap. 
                            For example, if you have a single-channel heatmap, set this to 1.
            output_dim (int): Dimensionality of the output hidden vector.
        """
        super(HeatmapCNN, self).__init__()
        # First convolution: from in_channels to 16 filters.
        self.conv1 = nn.Conv2d(in_channels, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        # Second convolution: from 16 to 32 filters.
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        # Third convolution: from 32 to 64 filters.
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(64)
        # Use max pooling between layers.
        self.pool = nn.MaxPool2d(2)
        # Use adaptive average pooling to reduce any spatial size to 1x1.
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        # Final fully connected layer projects from 64 to output_dim.
        self.fc = nn.Linear(64, output_dim)
    
    def forward(self, x):
        """
        Args:
            x: Input heatmap tensor with shape [batch_size, in_channels, H, W]
        Returns:
            A tensor of shape [batch_size, output_dim] representing the summarized features.
        """
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        #x = F.relu(self.bn2(self.conv2(x)))
        #x = self.pool(x)
        #x = F.relu(self.bn3(self.conv3(x)))
        #x = self.pool(x)
        x = self.adaptive_pool(x)  # shape now becomes [batch_size, 64, 1, 1]
        x = x.view(x.size(0), -1)    # flatten to [batch_size, 64]
        x = self.fc(x)               # shape: [batch_size, output_dim]
        return x

class TeamGAT(nn.Module):
    def __init__(self, num_teams, input_dim, hidden_dim, num_heads=2, num_layers=2, dropout=0.1):
        super().__init__()
        
        # GAT layers
        self.gat_layers = nn.ModuleList()
        self.gat_layers.append(GATConv(input_dim, hidden_dim, heads=num_heads, dropout=dropout))
        
        for _ in range(num_layers - 1):
            self.gat_layers.append(GATConv(hidden_dim * num_heads, hidden_dim, heads=num_heads, dropout=dropout))
        
        self.out_linear = nn.Linear(hidden_dim * num_heads, input_dim)
    
    def forward(self, x, edge_index):
        # Get node features (team embeddings)
        edge_index = edge_index.to(x.device)
        
        # Apply GAT layers
        for gat in self.gat_layers:
            x = gat(x, edge_index)
            x = torch.relu(x)
        
        # Project back to input_dim (optional)
        x = self.out_linear(x)
        
        return x

class CoordConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, padding=1):
        super(CoordConv2d, self).__init__()
        # The input channels are increased by 2 (for x and y coordinates).
        self.conv = nn.Conv2d(in_channels + 2, out_channels, kernel_size=kernel_size, padding=padding)
    
    def forward(self, x):
        B, C, H, W = x.size()
        # Create normalized coordinate channels.
        xx_channel = torch.linspace(-1, 1, steps=W, device=x.device).unsqueeze(0).repeat(H,1)
        yy_channel = torch.linspace(-1, 1, steps=H, device=x.device).unsqueeze(1).repeat(1,W)
        xx_channel = xx_channel.unsqueeze(0).unsqueeze(0).repeat(B, 1, 1, 1)
        yy_channel = yy_channel.unsqueeze(0).unsqueeze(0).repeat(B, 1, 1, 1)
        x = torch.cat([x, xx_channel, yy_channel], dim=1)
        return self.conv(x)

class SimpleHeatmapCNNWithCoord(nn.Module):
    def __init__(self, in_channels=1, output_dim=32):
        super(SimpleHeatmapCNNWithCoord, self).__init__()
        # Replace standard conv with CoordConv.
        kern_size = 2
        pad_size = kern_size // 2
        self.coord_conv = CoordConv2d(in_channels, 8, kernel_size=kern_size, padding=pad_size)
        self.bn1 = nn.BatchNorm2d(8)
        self.pool = nn.MaxPool2d(2)
        # Simple spatial attention layer.
        #self.attn_conv = nn.Conv2d(8, 1, kernel_size=1)  # generates a single-channel attention map
        self.adaptive_pool = nn.AdaptiveMaxPool2d((8, 8))
        self.fc = nn.Linear(8*8*8, output_dim)
    
    def forward(self, x):
        x = F.relu(self.bn1(self.coord_conv(x)))  # output shape: [B, 8, H, W]
        x = self.pool(x)                          # reduce spatial dimensions.
        
        # Compute spatial attention mask.
        #attn = torch.sigmoid(self.attn_conv(x))   # shape: [B, 1, H, W]
        # Multiply feature maps by the attention mask.
        #x = x * attn
        
        x = self.adaptive_pool(x)                 # shape: [B, 8, 1, 1]
        x = x.view(x.size(0), -1)                 # flatten to [B, 8]
        x = self.fc(x)                           # project to output_dim.
        return x

class TeamEmbedding(nn.Module):
    def __init__(self, embed_dim, num_teams, mu_sigma, pad_idx=0, stats_hidden_dim=None, cnn_hidden_dim=64,
                coupled=False, device='cuda', training_embeds=True,gnn_hidden_dim=32, gnn_layers=1,standardize = True):
        """
        Args:
            embed_dim: Dimensionality of the team embedding.
            num_teams: Number of teams.
            mu_sigma: Tuple (mu_atk, sigma_atk, mu_def, sigma_def).
            pad_idx: Padding index for the embedding.
            stats_hidden_dim: Hidden dimension for the prediction MLP.
            coupled: If True, uses a coupled prediction branch.
            device: Device string.
            training_embeds: If True, uses only the last row of the sequence (for training);
                            if False, applies the transformations to the entire sequence.
        """
        super(TeamEmbedding, self).__init__()
        self.device = device
        self.training_embeds = training_embeds
        self.standardize = standardize
        self.mu_atk, self.sigma_atk, self.mu_def, self.sigma_def = mu_sigma

        self.mu_atk = self.mu_atk.to(self.device)
        self.sigma_atk = self.sigma_atk.to(self.device)
        self.mu_def = self.mu_def.to(self.device)
        self.sigma_def = self.sigma_def.to(self.device)
        self.stats_dim = len(self.mu_atk[0]) + len(self.mu_def[0])

        self.coupled = coupled

        # Embedding layer
        # Initial team embeddings (could use pretrained or learned embeddings)
        self.embedding = nn.Embedding(num_teams, embed_dim, padding_idx=pad_idx)
        # Standard team embeddings are trained with an MLP
        self.team_gat = TeamGAT(num_teams=num_teams, input_dim=embed_dim, hidden_dim=gnn_hidden_dim, num_heads=2,
                                num_layers = gnn_layers, dropout=0.1)
        
        # Convolutional layer to analyze heatmaps
        self.heatmap_cnn = SimpleHeatmapCNNWithCoordAndAttention(in_channels=1, output_dim=cnn_hidden_dim)
        
        # Embedding training module
        self.feat_extraction = CreateEmbMLP(embed_dim+2+cnn_hidden_dim, self.stats_dim, hidden_dim=stats_hidden_dim,
                                            num_layers=5, dropout=0.0)

        # Prediction module (MLP)
        if self.coupled:
            self.prediction = CreateEmbMLP((embed_dim + 2+cnn_hidden_dim)*2, 2*self.stats_dim,
                                        hidden_dim=stats_hidden_dim, num_layers=5,
                                        dropout=0.0)
        else:
            self.prediction = CreateEmbMLP(embed_dim + 2, self.stats_dim,
                                        hidden_dim=stats_hidden_dim, num_layers=3,
                                        dropout=0.0)

    def forward(self, batch,edge_index, key=None):
        if self.standardize:
            batch = standardize_stats(batch, self.mu_atk, self.sigma_atk, self.mu_def, self.sigma_def)
        batch_size = batch['home_team_atk'].shape[0]
        edge_index.to(self.device)
        

        # Obtain masks and lengths for both teams.
        valid_home_mask = batch['home_team_valid_mask']
        valid_away_mask = batch['away_team_valid_mask']
        home_scores_lengths = batch['home_team_scores_lengths'].to('cpu')
        away_scores_lengths = batch['away_team_scores_lengths'].to('cpu')

        if self.training_embeds:
            # Use only the last row of each sequence.
            home_team_atk = batch['home_team_atk'][:,-1:,:]
            home_team_def = batch['home_team_def'][:,-1:,:]
            away_team_atk = batch['away_team_atk'][:,-1:,:]
            away_team_def = batch['away_team_def'][:,-1:,:]

            home_team_is_home = batch['home_team_is_home'][:,-1:]
            home_team_standings = batch['home_team_standings'][:,-1:]
            home_team_heatmap = batch['home_team_player_heatmap_sequence'][:,-1:,:,:]
            #home_team_av_heatmap = torch.mean(batch['home_team_player_heatmap_sequence'][:,:-1,:,:], dim=1).unsqueeze(1)
            home_cnn_heatmap = self.heatmap_cnn(home_team_heatmap).unsqueeze(1)
            away_team_is_home = batch['away_team_is_home'][:,-1:]
            away_team_standings = batch['away_team_standings'][:,-1:]
            away_team_heatmap = batch['away_team_player_heatmap_sequence'][:,-1:,:,:]
            #away_team_av_heatmap = torch.mean(batch['away_team_player_heatmap_sequence'][:,:-1,:,:], dim=1).unsqueeze(1)
            away_cnn_heatmap = self.heatmap_cnn(away_team_heatmap).unsqueeze(1)

            # Stacking
            home_away_is_home = torch.cat([home_team_is_home, away_team_is_home], dim=0)
            home_away_standings = torch.cat([home_team_standings, away_team_standings], dim=0)
            home_away_heatmap = torch.cat([home_cnn_heatmap, away_cnn_heatmap], dim=0)
            

            home_team_indexes = batch['home_team_index'][:,-1:]
            away_team_indexes = batch['away_team_index'][:,-1:]
            home_team_league = batch['leagues'][:]
            away_team_league = batch['leagues'][:]
            
            home_team_embed = self.embedding(home_team_indexes)
            away_team_embed = self.embedding(away_team_indexes)
            home_away_embed = torch.cat([home_team_embed, away_team_embed], dim=0)
            
            
            
            # We pass the embeddings too to the GAT module
            updated_team_embeds = self.team_gat(self.embedding.weight, edge_index)  # shape: (num_teams, embed_dim)
            # Look up updated embeddings for the teams from the GNN.
            home_team_gat = updated_team_embeds[home_team_indexes]
            away_team_gat = updated_team_embeds[away_team_indexes]
            
            home_team_names = [name for names in batch['home_team_names'] for name in names[-1:]]
            away_team_names = [name for names in batch['away_team_names'] for name in names[-1:]]
            
            # Combine indexes and names.
            all_indexes = torch.cat([home_team_indexes, away_team_indexes], dim=0)
            all_names = home_team_names + away_team_names
            all_leagues = torch.cat([home_team_league, away_team_league], dim=0)
            
            
            # Combine attack and defense stats.
            home_stats = torch.cat([home_team_atk, home_team_def], dim=-1)
            away_stats = torch.cat([away_team_atk, away_team_def], dim=-1)
            labels = torch.cat([home_stats, away_stats], dim=0)
            labels = labels.squeeze(1)  # when using last row, squeeze the second dimension
        else:
            1+1
            # Use the entire sequence.
            #team_atk = batch[f'{key}_team_atk']      # shape: (B, seq_len, dim)
            #team_def = batch[f'{key}_team_def']
            #enemy_atk = batch[f'{key}_enemy_atk']
            #enemy_def = batch[f'{key}_enemy_def']

            #team_is_home = batch[f'{key}_team_is_home']  # shape: (B, seq_len, 1)
            #team_standings = batch[f'{key}_team_standings']
            #enemy_is_home = batch[f'{key}_enemy_is_home']
            #enemy_standings = batch[f'{key}_enemy_standings']

            # For indexes and names, assume that the whole sequence is provided;
            # You might decide to aggregate these (e.g. using the last element or a mean) for downstream usage.
            # Here we simply use the entire sequence for further processing.
            #team_indexes = batch[f'{key}_team_index']
            #enemy_indexes = batch[f'{key}_enemy_index']
            # For team names, we assume each sample contains a list of names (one per match)
            # and we take the last name in the sequence (or you might choose to do something else).
            #team_names = batch[f'{key}_team_names']
            #enemy_names = batch[f'{key}_enemy_names']
            
            #team_embed = self.embedding_layer(team_indexes)
            #enemy_embed = self.embedding_layer(enemy_indexes)
        
        #if self.training_embeds:
        #    labels = labels.squeeze(1)  # when using last row, squeeze the second dimension

        # Predict stats from embeddings.
        if self.coupled:
            
            if self.training_embeds:
                home_away_stats = torch.cat([home_away_embed, home_away_heatmap, home_away_is_home, home_away_standings], dim=-1)
                home_away_features = self.feat_extraction(home_away_stats).squeeze(1)
                
                home_away_input = torch.cat([home_team_gat, home_cnn_heatmap, home_team_is_home, home_team_standings,
                                        away_team_gat, away_cnn_heatmap, away_team_is_home, away_team_standings], dim=-1)
                predicted_stats = self.prediction(home_away_input)
                home_stats_pred = predicted_stats[..., :self.stats_dim]
                away_stats_pred = predicted_stats[..., self.stats_dim:]
                home_away_stats = torch.cat([home_stats_pred, away_stats_pred], dim=0).squeeze(1)
                
            else:
                1+1
                #home_away_input = torch.cat([team_embed, team_is_home, team_standings,
                #                        enemy_embed, enemy_is_home, enemy_standings], dim=-1)
                #predicted_stats = self.prediction(home_away_input)
                # When coupled, split predictions.
                #if key == 'home':
                #    valid_mask = valid_home_mask
                #else:
                #    valid_mask = valid_away_mask
                #team_pred = predicted_stats[..., :self.stats_dim]*valid_mask
                #enemy_pred = predicted_stats[..., self.stats_dim:]*valid_mask
                #
                #return team_embed,enemy_embed, team_pred, enemy_pred
        
        
        else:
            1+1
            #home_away_input = torch.cat([home_team_embed, home_team_is_home, home_team_standings,
            #                            away_team_embed, away_team_is_home, away_team_standings], dim=-1)
            #home_away_stats = self.prediction(home_away_input)

        return labels, home_away_stats, home_away_features, all_indexes, all_names, home_away_embed, all_leagues

    def _embeds_only(self, indexes):
        return self.embedding_layer(indexes)

# %%
torch.save(test_embedder.state_dict(), 'embeddings_128hid_1gnn_2heads_heatcnnsimplemax_888_128_nopad.pth')

# %%
mu_sigma = (mu_atk, sigma_atk, mu_def, sigma_def)
embed_dim = 256
gnn_hidden_dim = 128
gnn_layers = 1
stats_hidden_dim = 256
cnn_hidden_dim = 128

test_embedder = TeamEmbedding(embed_dim, num_teams=len(team2id), mu_sigma=mu_sigma,pad_idx=0,stats_hidden_dim=None,
                            cnn_hidden_dim=cnn_hidden_dim, coupled=True, device='cuda', training_embeds=True,
                            gnn_hidden_dim=gnn_hidden_dim, gnn_layers=gnn_layers)
#embedding_state = torch.load('embeddings_tanh_5_layers_test.pth')
#test_embedder.load_state_dict(embedding_state)

# %%
embed_state = torch.load('embeddings_32hid_1gnn_2heads.pth')
test_embedder.load_state_dict(embed_state)

# %%
import torch
import torch.nn as nn

def train_autoencoder_tweaked(model, train_loader, valid_loader, device, lr=1e-4, epochs=10, patience=5,
                    scheduler_factor=0.5, scheduler_patience=2):
    """
    Trains the model (autoencoder) using MSE loss with early stopping and a learning rate scheduler.
    
    The model's forward should return a tuple:
        (labels, predicted_stats, all_indexes, all_names, all_teams_embed)
    where:
        - labels: Ground truth stats (Tensor)
        - predicted_stats: The reconstructed stats (Tensor)
    
    Args:
        model: Your autoencoder model (e.g., TeamEmbedding).
        train_loader: DataLoader for training samples.
        valid_loader: DataLoader for validation samples.
        device: The device to use ('cuda' or 'cpu').
        lr: Learning rate.
        epochs: Maximum number of training epochs.
        patience: Number of epochs to wait for improvement in validation loss before stopping.
        scheduler_factor: Factor by which to reduce the learning rate.
        scheduler_patience: Number of epochs with no improvement after which LR is reduced.
    
    Returns:
        (train_losses, valid_losses): Lists of average loss per epoch (up to early stopping).
    """
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.MSELoss()
    #criterion = nn.SmoothL1Loss(beta=0.15) 
    #criterion = AsymmetricLoss(weight_over=2.0, weight_under=1.0)

    # Set up a learning rate scheduler that reduces LR when validation loss plateaus.
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
                                                        factor=scheduler_factor, 
                                                        patience=scheduler_patience, 
                                                        verbose=True)
    
    train_losses = []
    valid_losses = []
    match_losses = []

    best_valid_loss = float('inf')
    patience_counter = 0
    best_epoch = 0
    best_model_state = None

    for epoch in range(epochs):
        model.train()
        running_train_loss = 0.0

        for batch in train_loader:
            # Move all tensor data in the batch to the target device.
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            
            optimizer.zero_grad()
            # Forward pass: get labels and reconstructed stats.
            labels, predicted_stats, extracted_features, all_indexes, all_names, all_teams_embed,_ = model(batch,edges)
            rep_loss = criterion(extracted_features, labels)
            match_loss = criterion(predicted_stats, labels)
            loss = 0.5*rep_loss + match_loss
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * predicted_stats.size(0)
        
        epoch_train_loss = running_train_loss / len(train_loader.dataset)
        train_losses.append(epoch_train_loss)

        model.eval()
        running_valid_loss = 0.0
        running_match_loss = 0.0
        with torch.no_grad():
            for batch in valid_loader:
                for key in batch:
                    if torch.is_tensor(batch[key]):
                        batch[key] = batch[key].to(device)
                
                labels, predicted_stats, extracted_features, all_indexes, all_names, all_teams_embed,_ = model(batch,edges)
                rep_loss = criterion(extracted_features, labels)
                match_loss = criterion(predicted_stats, labels)
                loss = 0.5 *rep_loss + match_loss
                running_valid_loss += loss.item() * predicted_stats.size(0)
                running_match_loss += match_loss.item() * predicted_stats.size(0)
                
        
        epoch_valid_loss = running_valid_loss / len(valid_loader.dataset)
        epoch_match_loss = running_match_loss / len(valid_loader.dataset)
        valid_losses.append(epoch_valid_loss)
        match_losses.append(epoch_match_loss)
        

        # Step the scheduler with the validation loss.
        scheduler.step(epoch_valid_loss)

        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {epoch_train_loss:.4f} | Valid Loss: {epoch_valid_loss:.4f} | Match Loss: {epoch_match_loss:.4f}")

        # Early stopping check.
        if epoch_valid_loss < best_valid_loss:
            best_valid_loss = epoch_valid_loss
            best_epoch = epoch
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch+1}. Best validation loss: {best_valid_loss:.4f} at epoch {best_epoch+1}.")
                break

    # Optionally, load the best model state.
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
    
    return train_losses, valid_losses, match_losses 


# Example usage:
# train_losses, valid_losses = train_autoencoder(model, train_loader, valid_loader, device='cuda', lr=1e-4, epochs=20, patience=5)



def plot_losses(train_losses, valid_losses):
    epochs = range(1, len(train_losses) + 1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, valid_losses, label="Valid Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Train vs. Validation Loss")
    plt.legend()
    plt.show()

class AsymmetricLoss(nn.Module):
    def __init__(self, weight_over=2.0, weight_under=1.0):
        super().__init__()
        self.weight_over = weight_over
        self.weight_under = weight_under
        
    def forward(self, preds, targets):
        diff = preds - targets
        loss = torch.where(diff >= 0,
                           self.weight_over * diff.pow(2),
                           self.weight_under * diff.pow(2))
        return loss.mean()

# Use in training:
#criterion = AsymmetricLoss(weight_over=2.0, weight_under=1.0)


# Example usage:
# train_losses, valid_losses = train_autoencoder(model, train_loader, valid_loader, device='cuda', lr=1e-4, epochs=20)

# %%
torch.save(test_embedder.state_dict(), 'embeddings_128hid_1gnn_2heads_reluleagues_nocards.pth')

# %%
train_losses, valid_losses, match_losses = train_autoencoder_tweaked(test_embedder, train_loader, val_loader, device='cuda',
                                                        lr=1e-3, epochs=100, patience=5,
                                                        scheduler_factor=0.1, scheduler_patience=2)
# Out:
# Epoch 1/100 - Train Loss: 2.9866 | Valid Loss: 3.0182 | Match Loss: 2.0225
# Epoch 2/100 - Train Loss: 2.9437 | Valid Loss: 2.9671 | Match Loss: 2.0142
# Epoch 3/100 - Train Loss: 2.9054 | Valid Loss: 2.9260 | Match Loss: 1.9796
# Epoch 4/100 - Train Loss: 2.8698 | Valid Loss: 2.8989 | Match Loss: 1.9547
# Epoch 5/100 - Train Loss: 2.8349 | Valid Loss: 2.8574 | Match Loss: 1.9157
# Epoch 6/100 - Train Loss: 2.8046 | Valid Loss: 2.8244 | Match Loss: 1.8853
# Epoch 7/100 - Train Loss: 2.7799 | Valid Loss: 2.8102 | Match Loss: 1.8737
# Epoch 8/100 - Train Loss: 2.7623 | Valid Loss: 2.7886 | Match Loss: 1.8537
# Epoch 9/100 - Train Loss: 2.7465 | Valid Loss: 2.7653 | Match Loss: 1.8317
# Epoch 10/100 - Train Loss: 2.7408 | Valid Loss: 2.7788 | Match Loss: 1.8440
# Epoch 11/100 - Train Loss: 2.7252 | Valid Loss: 2.7678 | Match Loss: 1.8368
# Epoch 12/100 - Train Loss: 2.7017 | Valid Loss: 2.7465 | Match Loss: 1.8176
# Epoch 13/100 - Train Loss: 2.6940 | Valid Loss: 2.7387 | Match Loss: 1.8109
# Epoch 14/100 - Train Loss: 2.6685 | Valid Loss: 2.7193 | Match Loss: 1.7764
# Epoch 15/100 - Train Loss: 2.6889 | Valid Loss: 2.6991 | Match Loss: 1.7645
# Epoch 16/100 - Train Loss: 2.6424 | Valid Loss: 2.6549 | Match Loss: 1.7255
# Epoch 17/100 - Train Loss: 2.6049 | Valid Loss: 2.6573 | Match Loss: 1.7262
# Epoch 18/100 - Train Loss: 2.5932 | Valid Loss: 2.6334 | Match Loss: 1.7048
# Epoch 19/100 - Train Loss: 2.5761 | Valid Loss: 2.6217 | Match Loss: 1.6988
# Epoch 20/100 - Train Loss: 2.5619 | Valid Loss: 2.6184 | Match Loss: 1.7001
# Epoch 21/100 - Train Loss: 2.5507 | Valid Loss: 2.5965 | Match Loss: 1.6880
# Epoch 22/100 - Train Loss: 2.5387 | Valid Loss: 2.6155 | Match Loss: 1.6848
# Epoch 23/100 - Train Loss: 2.5302 | Valid Loss: 2.5667 | Match Loss: 1.6786
# Epoch 24/100 - Train Loss: 2.5094 | Valid Loss: 2.5925 | Match Loss: 1.6720
# Epoch 25/100 - Train Loss: 2.5048 | Valid Loss: 2.5398 | Match Loss: 1.6628
# Epoch 26/100 - Train Loss: 2.4840 | Valid Loss: 2.5338 | Match Loss: 1.6586
# Epoch 27/100 - Train Loss: 2.4695 | Valid Loss: 2.5118 | Match Loss: 1.6523
# Epoch 28/100 - Train Loss: 2.4608 | Valid Loss: 2.5045 | Match Loss: 1.6480
# Epoch 29/100 - Train Loss: 2.4532 | Valid Loss: 2.5430 | Match Loss: 1.6459
# Epoch 30/100 - Train Loss: 2.4480 | Valid Loss: 2.5235 | Match Loss: 1.6457
# Epoch 31/100 - Train Loss: 2.4338 | Valid Loss: 2.4902 | Match Loss: 1.6404
# Epoch 32/100 - Train Loss: 2.4788 | Valid Loss: 2.5179 | Match Loss: 1.6465
# Epoch 33/100 - Train Loss: 2.5001 | Valid Loss: 2.5775 | Match Loss: 1.6477
# Epoch 34/100 - Train Loss: 2.5091 | Valid Loss: 2.5452 | Match Loss: 1.6407
# Epoch 35/100 - Train Loss: 2.4772 | Valid Loss: 2.5391 | Match Loss: 1.6403
# Epoch 36/100 - Train Loss: 2.4681 | Valid Loss: 2.5316 | Match Loss: 1.6389
# Epoch 37/100 - Train Loss: 2.4592 | Valid Loss: 2.5253 | Match Loss: 1.6379
# Epoch 38/100 - Train Loss: 2.4540 | Valid Loss: 2.5246 | Match Loss: 1.6378
# Epoch 39/100 - Train Loss: 2.4533 | Valid Loss: 2.5239 | Match Loss: 1.6377
# Early stopping triggered at epoch 39. Best validation loss: 2.4902 at epoch 31.

# %%
plot_losses(train_losses, valid_losses)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize_embeddings(model, test_loader, device='cuda'):
    """
    Visualize team embeddings from the test dataloader using t-SNE.
    
    The model's forward is assumed to return a tuple:
         (labels, predicted_stats, team_ids, names, embeddings)
    where:
         - embeddings: Tensor of shape (batch_size, d) or (batch_size, 1, d)
         - team_ids:   Tensor of shape (batch_size,) with team IDs
         - names:      A list of team names for each sample in the batch
         
    Only one embedding per unique team is selected globally (across all batches).
    """
    model.eval()
    all_embeddings = []
    all_team_ids = []  # list of team IDs (as Python ints)
    all_names = []     # corresponding team names

    with torch.no_grad():
        for batch in test_loader:
            # Move tensors in the batch to the target device.
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            # Assume model returns: (labels, predicted_stats, team_ids, names, embeddings)
            _, _,_, team_ids, names, embeddings,_ = model(batch,edges)
            team_ids = team_ids.squeeze().cpu().tolist()  # ensure team_ids is a list of scalars
            all_team_ids.extend(team_ids)
            all_names.extend(names)
            all_embeddings.append(embeddings.cpu().numpy())

    # Concatenate embeddings from all batches.
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    
    # If embeddings have an extra singleton dimension (e.g. shape (batch_size, 1, d)), squeeze it.
    if all_embeddings.ndim == 3 and all_embeddings.shape[1] == 1:
        all_embeddings = np.squeeze(all_embeddings, axis=1)
    
    # Select one embedding per unique team globally.
    unique_embeddings = []
    unique_team_ids = []
    unique_names = []
    seen = set()
    for i, tid in enumerate(all_team_ids):
        if tid not in seen:
            seen.add(tid)
            # Squeeze the embedding in case it has an extra dimension.
            unique_embeddings.append(np.squeeze(all_embeddings[i]))
            unique_team_ids.append(tid)
            unique_names.append(all_names[i])
    unique_embeddings = np.array(unique_embeddings)

    # Apply t-SNE to reduce dimensions to 2.
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    tsne_results = tsne.fit_transform(unique_embeddings)

    # Plot the t-SNE result.
    plt.figure(figsize=(10, 8))
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], s=10, alpha=0.7, c='blue')

    # Annotate each unique team point with its name.
    for i, name in enumerate(unique_names):
        plt.annotate(name, (tsne_results[i, 0], tsne_results[i, 1]),
                     fontsize=10, alpha=0.75)

    plt.title("t-SNE Visualization of Unique Team Embeddings")
    plt.xlabel("t-SNE Dimension 1")
    plt.ylabel("t-SNE Dimension 2")
    plt.tight_layout()
    plt.show()

# Example usage:
# visualize_embeddings(test_embedder, test_loader, device='cuda')

# %%
visualize_embeddings(test_embedder, test_loader, device='cuda')

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

def visualize_embeddings(model, test_loader, device='cuda'):
    """
    Visualize team embeddings from the test dataloader using t-SNE after centering and scaling.

    The model's forward is assumed to return a tuple:
        (labels, predicted_stats, team_ids, names, embeddings)
    where:
        - embeddings: Tensor of shape (batch_size, d) or (batch_size, 1, d)
        - team_ids:   Tensor of shape (batch_size,) with team IDs
        - names:      A list of team names for each sample in the batch
        
    Only one embedding per unique team is selected globally (across all batches).
    """
    model.eval()
    all_embeddings = []
    all_team_ids = []  # list of team IDs (as Python ints)
    all_names = []     # corresponding team names

    with torch.no_grad():
        for batch in test_loader:
            # Move tensors in the batch to the target device.
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            # Assume model returns: (labels, predicted_stats, team_ids, names, embeddings)
            _, _,_, team_ids, names, embeddings,_ = model(batch,edges)
            team_ids = team_ids.squeeze().cpu().tolist()  # ensure team_ids is a list of scalars
            all_team_ids.extend(team_ids)
            all_names.extend(names)
            all_embeddings.append(embeddings.cpu().numpy())

    # Concatenate embeddings from all batches.
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    
    # If embeddings have an extra singleton dimension (e.g. shape (batch_size, 1, d)), squeeze it.
    if all_embeddings.ndim == 3 and all_embeddings.shape[1] == 1:
        all_embeddings = np.squeeze(all_embeddings, axis=1)
    
    # Select one embedding per unique team globally.
    unique_embeddings = []
    unique_team_ids = []
    unique_names = []
    seen = set()
    for i, tid in enumerate(all_team_ids):
        if tid not in seen:
            seen.add(tid)
            # Squeeze the embedding in case it has an extra dimension.
            unique_embeddings.append(np.squeeze(all_embeddings[i]))
            unique_team_ids.append(tid)
            unique_names.append(all_names[i])
    unique_embeddings = np.array(unique_embeddings)

    # Center and scale the embeddings before applying t-SNE.
    scaler = StandardScaler()
    unique_embeddings = scaler.fit_transform(unique_embeddings)

    # Apply t-SNE to reduce dimensions to 2.
    tsne = TSNE(n_components=2, perplexity=2, random_state=42)
    tsne_results = tsne.fit_transform(unique_embeddings)

    # Plot the t-SNE result.
    plt.figure(figsize=(10, 8))
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], s=50, alpha=0.7, c='blue')

    # Annotate each unique team point with its name.
    for i, name in enumerate(unique_names):
        plt.annotate(name, (tsne_results[i, 0], tsne_results[i, 1]),
                     fontsize=10, alpha=0.75)

    plt.title("t-SNE Visualization of Unique Team Embeddings (Centered & Scaled)")
    plt.xlabel("t-SNE Dimension 1")
    plt.ylabel("t-SNE Dimension 2")
    plt.tight_layout()
    plt.show()

# Example usage:
# visualize_embeddings(test_embedder, test_loader, device='cuda')

# %%
test_embedder.to('cuda')
visualize_embeddings(test_embedder, test_loader, device='cuda')

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def visualize_embeddings_pca(model, test_loader, device='cuda', component_x=0, component_y=1):
    """
    Visualize team embeddings from the test dataloader using PCA.
    
    The model's forward is assumed to return a tuple:
        (labels, predicted_stats, team_ids, names, embeddings)
    where:
        - embeddings: Tensor of shape (batch_size, d) or (batch_size, 1, d)
        - team_ids:   Tensor of shape (batch_size,) with team IDs
        - names:      A list of team names for each sample in the batch
        
    Only one embedding per unique team is selected globally (across all batches).
    
    Parameters:
        model: The model from which to extract embeddings.
        test_loader: DataLoader providing test data.
        device: Device on which to run computations ('cuda' or 'cpu').
        component_x: Index of the PCA component to use for the x-axis (0-indexed).
        component_y: Index of the PCA component to use for the y-axis (0-indexed).
    """
    model.eval()
    all_embeddings = []
    all_team_ids = []  # list of team IDs (as Python ints)
    all_names = []     # corresponding team names

    with torch.no_grad():
        for batch in test_loader:
            # Move each tensor in the batch to the specified device.
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            # Assume model returns: (labels, predicted_stats, team_ids, names, embeddings)
            _, _,_, team_ids, names, embeddings,_ = model(batch,edges)
            # Squeeze team_ids so that we get scalars, then convert to list.
            team_ids = team_ids.squeeze().cpu().tolist()
            all_team_ids.extend(team_ids)
            all_names.extend(names)
            all_embeddings.append(embeddings.cpu().numpy())

    # Concatenate embeddings from all batches.
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    
    # If embeddings have an extra singleton dimension (shape (N,1,d)), squeeze it.
    if all_embeddings.ndim == 3 and all_embeddings.shape[1] == 1:
        all_embeddings = np.squeeze(all_embeddings, axis=1)
    
    # Select one embedding per unique team globally.
    unique_embeddings = []
    unique_team_ids = []
    unique_names = []
    seen = set()
    for i, tid in enumerate(all_team_ids):
        if tid not in seen:
            seen.add(tid)
            unique_embeddings.append(all_embeddings[i])
            unique_team_ids.append(tid)
            unique_names.append(all_names[i])
    unique_embeddings = np.array(unique_embeddings)

    # Ensure PCA computes enough components.
    n_components = max(component_x, component_y) + 1
    pca = PCA(n_components=n_components)
    pca_results = pca.fit_transform(unique_embeddings)

    # Extract the chosen components for visualization.
    x_vals = pca_results[:, component_x]
    y_vals = pca_results[:, component_y]

    # Plot the PCA results.
    plt.figure(figsize=(10, 8))
    plt.scatter(x_vals, y_vals, s=50, alpha=0.7, c='blue')

    # Annotate each unique team point with its name.
    for i, name in enumerate(unique_names):
        plt.annotate(name, (x_vals[i], y_vals[i]), fontsize=10, alpha=0.75)

    plt.title("PCA Visualization of Unique Team Embeddings")
    plt.xlabel(f"PCA Component {component_x + 1}")
    plt.ylabel(f"PCA Component {component_y + 1}")
    plt.tight_layout()
    plt.show()

# Example usage:
# visualize_embeddings_pca(test_embedder, test_loader, device='cuda', component_x=0, component_y=1)

# %%
visualize_embeddings_pca(test_embedder, test_loader, device='cuda', component_x=0, component_y=1)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def visualize_embeddings_pca(model, test_loader, device='cuda', component_x=0, component_y=1):
    """
    Visualize team embeddings from the test dataloader using PCA after centering and scaling.
    
    The model's forward is assumed to return a tuple:
         (labels, predicted_stats, team_ids, names, embeddings)
    where:
         - embeddings: Tensor of shape (batch_size, d) or (batch_size, 1, d)
         - team_ids:   Tensor of shape (batch_size,) with team IDs
         - names:      A list of team names for each sample in the batch
         
    Only one embedding per unique team is selected globally (across all batches).
    
    Parameters:
        model: The model from which to extract embeddings.
        test_loader: DataLoader providing test data.
        device: Device on which to run computations ('cuda' or 'cpu').
        component_x: Index of the PCA component to use for the x-axis (0-indexed).
        component_y: Index of the PCA component to use for the y-axis (0-indexed).
    """
    model.eval()
    all_embeddings = []
    all_team_ids = []  # list of team IDs (as Python ints)
    all_names = []     # corresponding team names

    with torch.no_grad():
        for batch in test_loader:
            # Move each tensor in the batch to the specified device.
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            # Assume model returns: (labels, predicted_stats, team_ids, names, embeddings)
            _, _,_, team_ids, names, embeddings,_ = model(batch,edges)
            # Squeeze team_ids so that we get scalars, then convert to list.
            team_ids = team_ids.squeeze().cpu().tolist()
            all_team_ids.extend(team_ids)
            all_names.extend(names)
            all_embeddings.append(embeddings.cpu().numpy())

    # Concatenate embeddings from all batches.
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    
    # If embeddings have an extra singleton dimension (shape (N,1,d)), squeeze it.
    if all_embeddings.ndim == 3 and all_embeddings.shape[1] == 1:
        all_embeddings = np.squeeze(all_embeddings, axis=1)
    
    # Select one embedding per unique team globally.
    unique_embeddings = []
    unique_team_ids = []
    unique_names = []
    seen = set()
    for i, tid in enumerate(all_team_ids):
        if tid not in seen:
            seen.add(tid)
            unique_embeddings.append(all_embeddings[i])
            unique_team_ids.append(tid)
            unique_names.append(all_names[i])
    unique_embeddings = np.array(unique_embeddings)

    # Center and scale the embeddings before applying PCA.
    scaler = StandardScaler()
    unique_embeddings = scaler.fit_transform(unique_embeddings)

    # Ensure PCA computes enough components.
    n_components = max(component_x, component_y) + 1
    pca = PCA(n_components=n_components)
    pca_results = pca.fit_transform(unique_embeddings)

    # Extract the chosen components for visualization.
    x_vals = pca_results[:, component_x]
    y_vals = pca_results[:, component_y]

    # Plot the PCA results.
    plt.figure(figsize=(10, 8))
    plt.scatter(x_vals, y_vals, s=50, alpha=0.7, c='blue')

    # Annotate each unique team point with its name.
    for i, name in enumerate(unique_names):
        plt.annotate(name, (x_vals[i], y_vals[i]), fontsize=10, alpha=0.75)

    plt.title("PCA Visualization of Unique Team Embeddings (Centered & Scaled)")
    plt.xlabel(f"PCA Component {component_x + 1}")
    plt.ylabel(f"PCA Component {component_y + 1}")
    plt.tight_layout()
    plt.show()

# Example usage:
# visualize_embeddings_pca(test_embedder, test_loader, device='cuda', component_x=0, component_y=1)

# %%
visualize_embeddings_pca(test_embedder, test_loader, device='cuda', component_x=1, component_y=2)

# %%
def test_embedding_equality_by_name(model, test_loader, device='cuda', atol=1e-6, rtol=1e-5):
    """
    For each unique team name in the test_loader, check whether all embeddings
    (returned by the model) for that team are equal (using torch.allclose).

    The model's forward is assumed to return a tuple:
         (_, team_ids, names, embeddings)
    where:
         - names: a list of team names (one per sample)
         - embeddings: Tensor of shape (batch_size, d)

    Args:
        model: The model (e.g., your TeamEmbedding module).
        test_loader: DataLoader for the test set.
        device: Device string.
        atol, rtol: Tolerances for torch.allclose.
    """
    model.eval()
    all_embeddings = []
    all_names = []  # list of team names

    with torch.no_grad():
        for batch in test_loader:
            for key in batch:
                if torch.is_tensor(batch[key]):
                    batch[key] = batch[key].to(device)
            # Assume model returns: (_, team_ids, names, embeddings)
            _,_, team_ids, names, embeddings = model(batch)
            all_names.extend(names)
            all_embeddings.append(embeddings.cpu())

    # Concatenate all embeddings along the batch dimension.
    all_embeddings = torch.cat(all_embeddings, dim=0)
    
    # Ensure the names list matches the number of embeddings.
    n_points = all_embeddings.shape[0]
    all_names = all_names[:n_points]

    # Group embeddings by team name.
    name_to_embeds = {}
    for i, name in enumerate(all_names):
        if name not in name_to_embeds:
            name_to_embeds[name] = []
        name_to_embeds[name].append(all_embeddings[i])

    # Check equality within each group.
    for name, embeds in name_to_embeds.items():
        if len(embeds) < 2:
            print(f"Team '{name}': Only one instance, skipping.")
        else:
            base = embeds[0]
            equal = all(torch.allclose(emb, base, atol=atol, rtol=rtol) for emb in embeds[1:])
            if equal:
                print(f"Team '{name}': Equal")
            else:
                print(f"Team '{name}': Not Equal")

# Example usage:
# test_embedding_equality_by_name(test_embedder, test_loader, device='cuda')

# %%
test_embedding_equality_by_name(test_embedder, test_loader, device='cuda')

# %%
test_embedder.to('cuda')
for key in batch_data:
                if torch.is_tensor(batch_data[key]):
                    batch_data[key] = batch_data[key].to('cuda')
labels_t, home_away_stats_t,_, all_indexes_t, all_names_t, all_teams_embed_t, all_leagues_t= test_embedder(batch_data,edges)

# %%
test_embedder.to('cuda')
for key in batch_data:
    if torch.is_tensor(batch_data[key]):
        batch_data[key] = batch_data[key].to('cuda')
team_embed,enemy_embed,team_pred, enemy_pred= test_embedder(batch_data, edges)

# %%
reference_t=torch.cat([mu_atk, mu_def], dim=0).to('cuda')
sigma_t = torch.cat([sigma_atk, sigma_def], dim=0).to('cuda')

# %%
test_ind = 106
torch.set_printoptions(sci_mode=False) 
((home_away_stats_t[test_ind]*sigma_t)-(labels_t[test_ind]*sigma_t))[4]
# Out:
# tensor(1.0578, device='cuda:0', dtype=torch.float64, grad_fn=<SelectBackward0>)

# %%
((home_away_stats_t[test_ind]*sigma_t)+reference_t)[4]
# Out:
# tensor(4.0578, device='cuda:0', dtype=torch.float64, grad_fn=<SelectBackward0>)

# %%
b_size = home_away_stats_t.shape[0]//2
home_away_stats_t =inverse_standardize_stats(home_away_stats_t, all_leagues_t, mu_atk, sigma_atk, mu_def, sigma_def)
home_corners = home_away_stats_t[:b_size,4]
away_corners = home_away_stats_t[b_size:,4]
home_names = all_names_t[:b_size]
away_names = all_names_t[b_size:]
labels_t = inverse_standardize_stats(labels_t, all_leagues_t, mu_atk, sigma_atk, mu_def, sigma_def)
home_labels = labels_t[:b_size,4]
away_labels = labels_t[b_size:,4]
all_corners = home_corners+away_corners
all_labels = home_labels+away_labels

# %%
# Define header with fixed-width columns.
header = (
    f"{'Home Name':<25} {'Home Predicted':<15} {'Home Corners':<15} "
    f"{'Away Name':<25} {'Away Predicted':<15} {'Away Corners':<15} "
    f"{'All Predicted':<15} {'All Corners':<15}"
)
print(header)
print("-" * len(header))

# Print each row with float values truncated to 2 decimal places.
for i in range(len(all_corners)):
    row = (
        f"{home_names[i]:<25} "
        f"{home_corners[i]:<15.2f} "
        f"{home_labels[i]:<15.2f} "
        f"{away_names[i]:<25} "
        f"{away_corners[i]:<15.2f} "
        f"{away_labels[i]:<15.2f} "
        f"{all_corners[i]:<15.2f} "
        f"{all_labels[i]:<15.2f}"
    )
    print(row)
# Out:
# Home Name                 Home Predicted  Home Corners    Away Name                 Away Predicted  Away Corners    All Predicted   All Corners
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# sheffield-united          3.55            5.00            crystal-palace            7.91            11.00           11.47           16.00
# manchester-city           4.94            6.00            chelsea                   2.36            2.00            7.30            8.00
# newcastle-united          4.59            4.00            manchester-city           5.97            5.00            10.56           9.00
# west-ham-united           7.39            9.00            leeds-united              6.03            5.00            13.42           14.00
# brighton-and-hove-albion  7.56            4.00            southampton               1.58            3.00            9.14            7.00
# manchester-city           5.03            5.00            chelsea                   3.94            2.00            8.97            7.00
# newcastle-united          12.76           12.00           leicester-city            1.22            1.00            13.98           13.00
# arsenal                   7.32            8.00            wolverhampton             3.19            4.00            10.50           12.00
# aston-villa               6.39            3.00            brighton-and-hove-albion  3.86            3.00            10.25           6.00
# brentford                 5.86            3.00            manchester-city           6.63            4.00            12.49           7.00
# chelsea                   9.68            10.00           newcastle-united          3.78            3.00            13.46           13.00
# manchester-united         7.26            11.00           wolverhampton             5.49            7.00            12.75           18.00
# southampton               3.32            1.00            fulham                    5.89            8.00            9.20            9.00
# chelsea                   9.45            9.00            arsenal                   1.59            1.00            11.03           10.00
# brentford                 8.18            7.00            west-ham-united           2.82            5.00            11.00           12.00
# everton                   4.69            8.00            manchester-city           4.33            6.00            9.02            14.00
# arsenal                   6.25            5.00            brighton-and-hove-albion  1.99            2.00            8.24            7.00
# leicester-city            2.34            4.00            liverpool                 5.94            4.00            8.28            8.00
# tottenham-hotspur         6.94            8.00            brentford                 4.87            2.00            11.80           10.00
# bournemouth               3.20            3.00            manchester-united         7.04            6.00            10.24           9.00
# fulham                    6.63            7.00            crystal-palace            6.32            4.00            12.95           11.00
# liverpool                 8.08            9.00            aston-villa               2.66            3.00            10.75           12.00
# wolverhampton             2.80            1.00            everton                   6.91            7.00            9.71            8.00
# nottingham-forest         3.35            3.00            arsenal                   8.15            6.00            11.50           9.00

# %%
all_corners = ((home_away_stats_t*sigma_t)-(labels_t*sigma_t))

# %%
barc_tensor=batch_data['home_team_player_heatmap_sequence'][169][-1].to('cpu')
mallorc_tensor = batch_data['away_team_player_heatmap_sequence'][169][-1].to('cpu')
plot_heatmap(barc_tensor, n_x, n_y, title="Barcelona", cmap='viridis')
plot_heatmap(mallorc_tensor, n_x, n_y, title="Mallorca", cmap='viridis')

# %%
test_idx = 68
at_tensor=batch_data['home_team_player_heatmap_sequence'][test_idx][-1].to('cpu')
emp_tensor = batch_data['away_team_player_heatmap_sequence'][test_idx][-1].to('cpu')
plot_heatmap(at_tensor, n_x, n_y, title=batch_data['home_team_names'][test_idx][-1], cmap='viridis')
plot_heatmap(emp_tensor, n_x, n_y, title=batch_data['home_enemy_names'][test_idx][-1], cmap='viridis')

# %%
all_header = atk_headers+def_headers

# %%
for i in range(len(batch_data['home_team_names'])):
    if batch_data['home_team_names'][i][-1]=='west-bromwich-albion':
        print(i,batch_data['home_enemy_names'][i][-1] )
# Out:
# 68 liverpool
# 190 west-ham-united

# %%
testmean = torch.mean(batch_data['home_team_player_heatmap_sequence'][:,:-1,:], dim=1)
testmean.shape
# Out:
# torch.Size([583, 96])

# %%
all_names_t
# Out:
# ['sheffield-united',
#  'manchester-city',
#  'newcastle-united',
#  'west-ham-united',
#  'brighton-and-hove-albion',
#  'manchester-city',
#  'newcastle-united',
#  'arsenal',
#  'aston-villa',
#  'brentford',
#  'chelsea',
#  'crystal-palace',
#  'everton',
#  'burnley',
#  'leeds-united',
#  'leicester-city',
#  'manchester-united',
#  'southampton',
#  'manchester-united',
#  'newcastle-united',
#  'wolverhampton',
#  'everton',
#  'aston-villa',
#  'bournemouth',
#  'southampton',
#  'tottenham-hotspur',
#  'nottingham-forest',
#  'luton-town',
#  'arsenal',
#  'brentford',
#  'burnley',
#  'sheffield-united',
#  'manchester-city',
#  'brighton-and-hove-albion',
#  'chelsea',
#  'brighton-and-hove-albion',
#  'liverpool',
#  'crystal-palace',
#  'fulham',
#  'bournemouth',
#  'everton',
#  'newcastle-united',
#  'tottenham-hotspur',
#  'west-ham-united',
#  'wolverhampton',
#  'nottingham-forest',
#  'crystal-palace',
#  'manchester-united',
#  'aston-villa',
#  'arsenal',
#  'brentford',
#  'brighton-and-hove-albion',
#  'burnley',
#  'chelsea',
#  'crystal-palace',
#  'liverpool',
#  'luton-town',
#  'tottenham-hotspur',
#  'manchester-city',
#  'sheffield-united',
#  'barcelona',
#  'cadiz',
#  'athletic-club',
#  'getafe',
#  'crystal-palace',
#  'chelsea',
#  'manchester-city',
#  'leeds-united',
#  'southampton',
#  'chelsea',
#  'leicester-city',
#  'wolverhampton',
#  'brighton-and-hove-albion',
#  'manchester-city',
#  'newcastle-united',
#  'nottingham-forest',
#  'bournemouth',
#  'leeds-united',
#  'tottenham-hotspur',
#  'west-ham-united',
#  'fulham',
#  'liverpool',
#  'burnley',
#  'sheffield-united',
#  'luton-town',
#  'brentford',
#  'chelsea',
#  'brighton-and-hove-albion',
#  'fulham',
#  'arsenal',
#  'manchester-city',
#  'everton',
#  'bournemouth',
#  'fulham',
#  'newcastle-united',
#  'nottingham-forest',
#  'wolverhampton',
#  'aston-villa',
#  'west-ham-united',
#  'west-ham-united',
#  'tottenham-hotspur',
#  'manchester-united',
#  'manchester-city',
#  'brentford',
#  'sheffield-united',
#  'brighton-and-hove-albion',
#  'burnley',
#  'luton-town',
#  'crystal-palace',
#  'chelsea',
#  'aston-villa',
#  'arsenal',
#  'liverpool',
#  'everton',
#  'newcastle-united',
#  'manchester-united',
#  'nottingham-forest',
#  'bournemouth',
#  'aston-villa',
#  'wolverhampton',
#  'fulham',
#  'wolverhampton',
#  'west-ham-united',
#  'tottenham-hotspur',
#  'atletico-madrid',
#  'huesca',
#  'osasuna',
#  'eibar']

# %%
[i for i in range(len(all_names_t)) if all_names_t[i]=='burnley']
# Out:
# [13, 30, 52, 82, 106]

# %%
all_header = atk_headers+def_headers
all_header[51]
# Out:
# 'total_yellowcards'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the errors for the entire batch, move to CPU, detach, and convert to numpy
errors = [home_away_stats_t[i].cpu().detach()[4]- 
          labels_t[i].cpu().detach()[4] for i in range(len(labels_t))]

# Convert list of tensors to NumPy and flatten them
errors = np.concatenate([e.numpy().flatten() for e in errors])

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(errors, bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Distribution of Errors for Corner Kicks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the errors for the entire batch, move to CPU, detach, and convert to numpy
errors = [(all_corners[i].cpu().detach() - 
        all_labels[i].cpu().detach()) for i in range(len(all_labels))]

# Convert list of tensors to NumPy and flatten them
errors = np.concatenate([e.numpy().flatten() for e in errors])

# Plot histogram
plt.figure(figsize=(8, 6))
plt.hist(errors, bins=32, edgecolor='black', alpha=0.7)
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Distribution of Errors for Corner Kicks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
6,14,25,57,69,99,119

# %%
all_names_t[119]
# Out:
# 'wolverhampton'

# %%
new_test = standardize_stats(batch_data, mu_atk, sigma_atk, mu_def, sigma_def)

# %%
new_test['home_team_def'].shape
# Out:
# torch.Size([583, 9, 30])

# %%
batch_data['home_team_player_heatmap_sequence'][:,-1:,:].shape
# Out:
# torch.Size([583, 1, 96])
