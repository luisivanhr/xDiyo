# %%
from football_scrape_xdiyo import *
from time import sleep
#from selenium.webdriver.chrome.service import Service 
#from selenium.webdriver.chrome.options import Options

# %%
league_name = 'La_Liga'
season_start = '23'
season_end = '24'
league_id = 8
season_id = 52376
num_rounds = 38
num_teams = 20

#Increase this waiting time if the browser doesn't have enough time for the website to load
waiting_time = 10
#Path to chromedriver
path='C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe'
extension_path = "C:/Users/luisi/Documents/Programming/Chromedriver/windscribe.crx"
profile_path = "user-data-dir=C:\\Users\\luisi\\AppData\\Local\\Google\\Chrome\\User Data\\SeleniumProfile"
#C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe
#C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe


#Specify the columns beforehand
columns = ['custom_id', 'match_id', 'season_id', 'season_year', 'round', 'home_id',
    'home_standing', 'home_team', 'home_score', 'away_id', 'away_standing', 'away_team', 'away_score',
    'home_total_cornerkicks', 'away_total_cornerkicks', 'home_total_shotsongoal','away_total_shotsongoal',
    'home_total_totalshotsongoal','away_total_totalshotsongoal','home_total_offsides','away_total_offsides',
    'home_total_totaltackle','away_total_totaltackle',
    'home_total_yellowcards','away_total_yellowcards','home_total_redcards','away_total_redcards']

# %%
#Once the data is given press Shift+Enter to execute
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, profile_path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)

# %%
league= pd.read_csv(f'{league_name}_{season_start}_{season_end}.csv')
extracted_league = league[columns]
# Overwrite the file
extracted_league.to_csv(f'{league_name}_{season_start}_{season_end}.csv')

# %%
recent_round = 29

#Increase this waiting time if the browser doesn't have enough time for the website to load
waiting_time = 10
#Path to chromedriver
path='C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe'
#C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe
#C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe

#Once the data is give press Shift+Enter to execute
scrape_league_recent(league_id, season_id, recent_round, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True)
merging = [f'{league_name}_{season_start}_{season_end}',f'{league_name}_{season_start}_{season_end}_recent' ]
merge_recent_leagues_columns(merging,columns)

# %%
league_name = 'Serie_B'
season_start = '20'
season_end = '21'
league_id = 53
season_id = 32622
num_rounds = 38
num_teams = 20
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(180)

# %%
league_name = 'Serie_B'
season_start = '21'
season_end = '22'
league_id = 53
season_id = 37642
num_rounds = 38
num_teams = 20
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(189)

# %%
league_name = 'Serie_B'
season_start = '22'
season_end = '23'
league_id = 53
season_id = 44226
num_rounds = 38
num_teams = 20
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(167)

# %%
league_name = 'Serie_B'
season_start = '23'
season_end = '24'
league_id = 53
season_id = 52947
num_rounds = 38
num_teams = 20
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(201)

# %%
league_name = 'Bundesliga_2'
season_start = '20'
season_end = '21'
league_id = 44
season_id = 29312
num_rounds = 34
num_teams = 18
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(170)

# %%
league_name = 'Bundesliga_2'
season_start = '21'
season_end = '22'
league_id = 44
season_id = 37168
num_rounds = 34
num_teams = 18
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, profile_path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(176)

# %%
league_name = 'Bundesliga_2'
season_start = '22'
season_end = '23'
league_id = 44
season_id = 42269
num_rounds = 34
num_teams = 18
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(204.5)

# %%
league_name = 'Bundesliga_2'
season_start = '23'
season_end = '24'
league_id = 44
season_id = 52607
num_rounds = 34
num_teams = 18
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 8
#       6 num_rounds = 34
#       7 num_teams = 18
# ----> 8 scrape_league_data(league_id, season_id, num_rounds, num_teams,
#       9                 league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
#
# File c:\Users\luisi\Documents\Programming\Python\Football\xDiyo\football_scrape_xdiyo.py:817, in scrape_league_data(league_id, season_id, num_rounds, num_teams, league_name, season_start, season_end, path, profile_path, waiting_time, with_lineups, with_xG, with_comments, with_heatmaps)
#     813 def scrape_league_data(league_id, season_id, num_rounds, num_teams,
#     814                     league_name, season_start, season_end, path, profile_path, waiting_time=10,
# ...

# %%
league_name = 'La_Liga_2'
season_start = '20'
season_end = '21'
league_id = 54
season_id = 32502
num_rounds = 42
num_teams = 22
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(170)

# %%
league_name = 'La_Liga_2'
season_start = '21'
season_end = '22'
league_id = 54
season_id = 37225
num_rounds = 42
num_teams = 22
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(170)

# %%
league_name = 'La_Liga_2'
season_start = '22'
season_end = '23'
league_id = 54
season_id = 42410
num_rounds = 42
num_teams = 22
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(170)

# %%
league_name = 'La_Liga_2'
season_start = '23'
season_end = '24'
league_id = 54
season_id = 52563
num_rounds = 42
num_teams = 22
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time, with_lineups=True, with_xG=True, with_heatmaps=True)
sleep(170)

# %%
service = ChromeService(executable_path=path)
options.add_extension(extension_path)
driver = webdriver.Chrome(service=Service(chromedriver_path), options=options)

options.add_argument("user-data-dir=C:\\Users\\luisi\\AppData\\Local\\Google\\Chrome\\User Data\\SeleniumProfile")

# %%
options = Options()
options.add_extension(extension_path)
#options.add_extension("C:\\Users\\luisi\\Documents\\Programming\\Chromedriver\\windscribe.crx")

# (Optional) Use existing Chrome profile if you've already logged into Windscribe
#options.add_argument("user-data-dir=path/to/your/custom/chrome_profile")
options.add_argument("user-data-dir=C:\\Users\\luisi\\AppData\\Local\\Google\\Chrome\\User Data\\SeleniumProfile")

# Launch Chrome
driver = webdriver.Chrome(service=ChromeService(path), options=options)

# Wait a bit for Windscribe to load
time.sleep(5)

# %%
options.add_extension("C:/Users/luisi/Documents/Programming/Chromedriver/windscribe.crx")
