# %%
from football_scrape_xdiyo import *

# %%
league_name = 'Pro_League'
season_start = '24'
season_end = '25'
league_id = 38
season_id = 61459
num_rounds = 30
num_teams = 16

#Increase this waiting time if the browser doesn't have enough time for the website to load
waiting_time = 20
#Path to chromedriver
path='C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe'
#C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe
#C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe

#Once the data is given press Shift+Enter to execute
scrape_league_data(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time,with_lineups=True,with_xG=True,with_comments=False,with_heatmaps=True)

# %%
league_name = 'Premier_League'
season_start = '24'
season_end = '25'
league_id = 17
season_id = 61627
num_rounds = 12
num_teams = 20

#Increase this waiting time if the browser doesn't have enough time for the website to load
waiting_time = 10
#Path to chromedriver
path='C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe'
#C:/Users/luisi/Documents/Programming/Chromedriver/chromedriver.exe
#C:/Users/luisi/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe

#Once the data is give press Shift+Enter to execute
scrape_league_recent(league_id, season_id, num_rounds, num_teams,
                league_name, season_start, season_end, path, waiting_time)
