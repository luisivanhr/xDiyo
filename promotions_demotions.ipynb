# %%
from utils.promotions_demotions import get_promotions_and_demotions

# %%
# Run once per league pair; seed earliest known promotions/demotions.
get_promotions_and_demotions(
    top_league="Serie_A",
    bottom_league="Serie_B",
    top_promoted=["carpi", "frosinone","bologna"],      # earliest top-league promotions
    bottom_promoted=["trapani","pisa","juve-stabia","pordenone","virtus-entella"],       # earliest bottom-league promotions
    bottom_demoted=["empoli", "frosinone", "chievoverona"],         # earliest bottom-league demotions
    data_dir=r"data/xDiyo_data_heatmaps",              # source CSV directory
    output_dir=r"data/xDiyo_data_promotions",          # where to write annotated CSVs
)
# Out:
# Earliest top league season for Pro_League: Pro_League_20_21.csv (start_year: 20)
# Initial top league promoted teams for 20: ['k-beerschot-va', 'oud-heverlee-leuven']
# Top league promoted teams for season starting 21: ['rfc-seraing', 'royale-union-saint-gilloise']
# Advancing top league from 20 to 21
# Top league promoted teams for season starting 22: ['kvc-westerlo']
# Advancing top league from 21 to 22
# Top league promoted teams for season starting 23: ['rwd-molenbeek']
# Advancing top league from 22 to 23
# Top league promoted teams for season starting 24: ['fcv-dender-eh', 'k-beerschot-va']
# Advancing top league from 23 to 24
