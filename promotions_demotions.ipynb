# %%
from utils.promotions_demotions import get_promotions_and_demotions

# %%
# Run once per league pair; seed earliest known promotions/demotions.
get_promotions_and_demotions(
    top_league="Premier_League",
    bottom_league="Championship",
    top_promoted=["bournemouth", "watford", "norwich-city"],      # earliest top-league promotions
    bottom_promoted=["barnsley","burton-albion","wigan-athletic"],       # earliest bottom-league promotions
    bottom_demoted=["aston-villa", "norwich-city", "newcastle-united"],         # earliest bottom-league demotions
    data_dir=r"data/xDiyo_data_heatmaps",              # source CSV directory
    output_dir=r"data/xDiyo_data_promotions",          # wDhere to write annotated CSVs
)
# Out:
# Earliest top league season for Premier_League: Premier_League_15_16.csv (start_year: 15)
# Initial top league promoted teams for 15: ['bournemouth', 'norwich-city', 'watford']
# Earliest bottom league season for Championship: Championship_16_17.csv (start_year: 16)
# Initial bottom league promoted teams for 16: ['barnsley', 'burton-albion', 'wigan-athletic']
# Initial bottom league demoted teams for 16: ['aston-villa', 'newcastle-united', 'norwich-city']
# Top league promoted teams for season starting 16: ['burnley', 'hull-city', 'middlesbrough']
# Bottom league remains at 16 while processing top league season starting 16.
# Advancing top league from 15 to 16
# Top league promoted teams for season starting 17: ['brighton-and-hove-albion', 'huddersfield-town', 'newcastle-united']
# Bottom league promoted teams for season starting 17: ['bolton-wanderers', 'millwall', 'sheffield-united']
# Bottom league demoted teams for season starting 17: ['hull-city', 'middlesbrough', 'sunderland']
# ...
